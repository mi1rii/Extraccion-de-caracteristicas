# %% [markdown]
# ### Actividad AG_1.2
#
# Ivanna Maldonado Cervantes
#
# Paula Simonetta Madrid Pérez
#
# Ania Diaz Gonzalez
#
# Miranda Eugenia Colorado Arróniz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('projectos_forvia.csv')

# %%
df = df.drop(df.index[245]).reset_index(drop=True)

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Number                245 non-null    object
#  1   Active                245 non-null    object
#  2   Project Name          245 non-null    object
#  3   Project Type          245 non-null    object
#  4   Geographical scope    245 non-null    object
#  5   Project manager       245 non-null    object
#  6   State                 245 non-null    object
#  7   Percent complete      245 non-null    float64
#  8   Project size          245 non-null    object
#  9   Project organization  245 non-null    object
#  10  Planned Go Live date  245 non-null    object
#  11  Project target phase  72 non-null     object
#  12  Actual Go Live date   48 non-null     object
#  13  Actual end date       0 non-null      float64
#  14  BG                    245 non-null    object
#  15  Closed                1 non-null      object
#  16  Domain                245 non-null    object
#  17  Domain Path           245 non-null    object
#  18  Last WAR              232 non-null    object
#  19  Project Health        232 non-null    object
#  20  Project type          245 non-null    object
#  21  Recurrent activity    245 non-null    object
#  22  Planned start date    245 non-null    object
#  23  Actual start date     227 non-null    object
#  24  On-hold               245 non-null    object
# dtypes: float64(2), object(23)
# memory usage: 48.0+ KB
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    173
# Actual Go Live date     197
# Actual end date         245
# BG                        0
# Closed                  244
# Domain                    0
# Domain Path               0
# Last WAR                 13
# Project Health           13
# Project type              0
# Recurrent activity        0
# Planned start date        0
# Actual start date        18
# On-hold                   0
# dtype: int64

# %%
df["Percent complete"] = df["Percent complete"].astype(str).str.replace("%", "", regex=False)
df["Percent complete"] = pd.to_numeric(df["Percent complete"], errors="coerce")

# %%
df = df.drop(columns=["Actual end date", "Closed", "Domain Path", "Actual Go Live date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Number                245 non-null    object
#  1   Active                245 non-null    object
#  2   Project Name          245 non-null    object
#  3   Project Type          245 non-null    object
#  4   Geographical scope    245 non-null    object
#  5   Project manager       245 non-null    object
#  6   State                 245 non-null    object
#  7   Percent complete      245 non-null    float64
#  8   Project size          245 non-null    object
#  9   Project organization  245 non-null    object
#  10  Planned Go Live date  245 non-null    object
#  11  Project target phase  72 non-null     object
#  12  BG                    245 non-null    object
#  13  Domain                245 non-null    object
#  14  Last WAR              232 non-null    object
#  15  Project Health        232 non-null    object
#  16  Project type          245 non-null    object
#  17  Recurrent activity    245 non-null    object
#  18  Planned start date    245 non-null    object
#  19  Actual start date     227 non-null    object
#  20  On-hold               245 non-null    object
# dtypes: float64(1), object(20)
# memory usage: 40.3+ KB

# %% [markdown]
# #### **Procesamos outliers y nulos**

# %%
df["Planned start date 2"] = pd.to_datetime(df["Planned start date"], dayfirst=True, errors='coerce')

# %%
sum = int(df["Planned start date 2"].isnull().sum())
sum
# Out:
# 133

# %%
df["Planned start date 3"] = df["Planned start date"].str.extract(r'(\d{1,2}/\d{1,2}/\d{4})')

# %%
sum = int(df["Planned start date 3"].isnull().sum())
sum
# Out:
# 0

# %%
df[df["Planned start date 2"].isnull()][["Planned start date", "Planned start date 2", "Planned start date 3"]]
# Out:
#       Planned start date Planned start date 2 Planned start date 3
# 1    18/01/2024 08:00:00                  NaT           18/01/2024
# 7    14/10/2024 08:00:00                  NaT           14/10/2024
# 8    14/02/2025 08:00:00                  NaT           14/02/2025
# 9    19/09/2024 08:00:00                  NaT           19/09/2024
# 10   21/10/2024 14:00:00                  NaT           21/10/2024
# ..                   ...                  ...                  ...
# 235  28/03/2025 06:00:00                  NaT           28/03/2025
# 238  28/10/2024 08:00:00                  NaT           28/10/2024
# 239  21/01/2025 08:00:00                  NaT           21/01/2025
# 240  25/03/2025 08:00:00                  NaT           25/03/2025
# 241  23/04/2024 08:00:00                  NaT           23/04/2024
#
# [133 rows x 3 columns]

# %%
df['Planned start date'] = pd.to_datetime(df['Planned start date 3'], format='%d/%m/%Y', dayfirst=True, errors='coerce')

# %%
df[df["Planned start date 2"].isnull()][["Planned start date", "Planned start date 2", "Planned start date 3"]]
# Out:
#     Planned start date Planned start date 2 Planned start date 3
# 1           2024-01-18                  NaT           18/01/2024
# 7           2024-10-14                  NaT           14/10/2024
# 8           2025-02-14                  NaT           14/02/2025
# 9           2024-09-19                  NaT           19/09/2024
# 10          2024-10-21                  NaT           21/10/2024
# ..                 ...                  ...                  ...
# 235         2025-03-28                  NaT           28/03/2025
# 238         2024-10-28                  NaT           28/10/2024
# 239         2025-01-21                  NaT           21/01/2025
# 240         2025-03-25                  NaT           25/03/2025
# 241         2024-04-23                  NaT           23/04/2024
#
# [133 rows x 3 columns]

# %%
df.drop(columns=["Planned start date 2", "Planned start date 3"], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Number                245 non-null    object
#  1   Active                245 non-null    object
#  2   Project Name          245 non-null    object
#  3   Project Type          245 non-null    object
#  4   Geographical scope    245 non-null    object
#  5   Project manager       245 non-null    object
#  6   State                 245 non-null    object
#  7   Percent complete      245 non-null    float64
#  8   Project size          245 non-null    object
#  9   Project organization  245 non-null    object
#  10  Planned Go Live date  245 non-null    object
#  11  Project target phase  72 non-null     object
#  12  BG                    245 non-null    object
#  13  Domain                245 non-null    object
#  14  Last WAR              232 non-null    object
#  15  Project Health        232 non-null    object
#  16  Project type          245 non-null    object
#  17  Recurrent activity    245 non-null    object
#  18  Planned start date    245 non-null    datetime64[ns]
#  19  Actual start date     227 non-null    object
#  20  On-hold               245 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(19)
# memory usage: 40.3+ KB

# %%
df.isnull().sum()
# Out:
# Number                    0
# Active                    0
# Project Name              0
# Project Type              0
# Geographical scope        0
# Project manager           0
# State                     0
# Percent complete          0
# Project size              0
# Project organization      0
# Planned Go Live date      0
# Project target phase    173
# BG                        0
# Domain                    0
# Last WAR                 13
# Project Health           13
# Project type              0
# Recurrent activity        0
# Planned start date        0
# Actual start date        18
# On-hold                   0
# dtype: int64

# %% [markdown]
# ### project target phase, last war, project health, actual start day (str)

# %%
df["Project target phase"] =df["Project target phase"].fillna("NA") 
df["Last WAR"] =df["Last WAR"].fillna("NA")
df["Actual start date"] =df["Actual start date"].fillna("NA")

# %%
df["Project Health"] =df["Project Health"].fillna('Red')

# %%
df.isnull().sum()
# Out:
# Number                  0
# Active                  0
# Project Name            0
# Project Type            0
# Geographical scope      0
# Project manager         0
# State                   0
# Percent complete        0
# Project size            0
# Project organization    0
# Planned Go Live date    0
# Project target phase    0
# BG                      0
# Domain                  0
# Last WAR                0
# Project Health          0
# Project type            0
# Recurrent activity      0
# Planned start date      0
# Actual start date       0
# On-hold                 0
# dtype: int64

# %% [markdown]
# #### **Project Type**

# %%
tabla_freq = df['Project Type'].value_counts().reset_index()
tabla_freq
# Out:
#                                     Project Type  count
# 0                              Shopfloor JIT/TCO     80
# 1                                  FCS roll-outs     75
# 2                        New software or release     46
# 3                              Shopfloor LES/NEO     13
# 4   Studies / Moves / Solution Selection / Other      8
# 5                        New Site infrastructure      7
# 6                   Overall Project Coordination      6
# 7                              Shopfloor DMC/SPC      5
# 8                             New infrastructure      3
# 9                                           ITAC      1
# 10                                  Carve-out/in      1

# %%
# filtro con los valores más relevantes de la variable 
filtro = tabla_freq[tabla_freq['count']>1]
filtro
# Out:
#                                    Project Type  count
# 0                             Shopfloor JIT/TCO     80
# 1                                 FCS roll-outs     75
# 2                       New software or release     46
# 3                             Shopfloor LES/NEO     13
# 4  Studies / Moves / Solution Selection / Other      8
# 5                       New Site infrastructure      7
# 6                  Overall Project Coordination      6
# 7                             Shopfloor DMC/SPC      5
# 8                            New infrastructure      3

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index = filtro.set_index('Project Type')
filtro_index
# Out:
#                                               count
# Project Type
# Shopfloor JIT/TCO                                80
# FCS roll-outs                                    75
# New software or release                          46
# Shopfloor LES/NEO                                13
# Studies / Moves / Solution Selection / Other      8
# New Site infrastructure                           7
# Overall Project Coordination                      6
# Shopfloor DMC/SPC                                 5
# New infrastructure                                3

# %%
# realizamos gráfico de barras
filtro_index.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('Project Type')
plt.xlabel('Tipo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #### **Geographical Scope**

# %%
tabla_freq1 = df['Geographical scope'].value_counts().reset_index()
tabla_freq1
# Out:
#     Geographical scope  count
# 0           WORLD WIDE     20
# 1               BRAZIL      9
# 2            PUEBLA HQ      7
# 3             BRAGANCA      6
# 4    PARIS TECH CENTER      5
# ..                 ...    ...
# 121              JAPAN      1
# 122        JANGAN FHS       1
# 123             JANGAN      1
# 124         HERRENBERG      1
# 125        NANTERRE HQ      1
#
# [126 rows x 2 columns]

# %%
# filtro con los valores más relevantes de la variable 
filtro1 = tabla_freq1[tabla_freq1['count']>3]
filtro1
# Out:
#              Geographical scope  count
# 0                    WORLD WIDE     20
# 1                        BRAZIL      9
# 2                     PUEBLA HQ      7
# 3                      BRAGANCA      6
# 4             PARIS TECH CENTER      5
# 5   MLADA BOLESLAV FCM Bezdecin      5
# 6     LIPPSTADT 2 HQH & FES R&D      5
# 7                        GOIANA      4
# 8                           NAO      4
# 9            MLADA BOLESLAV FIS      4
# 10                  LIPPSTADT 1      4

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index1 = filtro1.set_index('Geographical scope')
filtro_index1
# Out:
#                              count
# Geographical scope
# WORLD WIDE                      20
# BRAZIL                           9
# PUEBLA HQ                        7
# BRAGANCA                         6
# PARIS TECH CENTER                5
# MLADA BOLESLAV FCM Bezdecin      5
# LIPPSTADT 2 HQH & FES R&D        5
# GOIANA                           4
# NAO                              4
# MLADA BOLESLAV FIS               4
# LIPPSTADT 1                      4

# %%
# realizamos gráfico de barras
filtro_index1.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('Geographical Scope')
plt.xlabel('Scope')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
idx = df[df["Geographical scope"] == "WORLD WIDE"].index
df = df.drop(idx)

# %%
tabla_freq1 = df['Geographical scope'].value_counts().reset_index()
tabla_freq1
# Out:
#               Geographical scope  count
# 0                         BRAZIL      9
# 1                      PUEBLA HQ      7
# 2                       BRAGANCA      6
# 3      LIPPSTADT 2 HQH & FES R&D      5
# 4    MLADA BOLESLAV FCM Bezdecin      5
# ..                           ...    ...
# 120                  JANGAN FHS       1
# 121                       JANGAN      1
# 122                   HERRENBERG      1
# 123                  GIARMATA HQ      1
# 124                MONTERREY FIS      1
#
# [125 rows x 2 columns]

# %%
# filtro con los valores más relevantes de la variable 
filtro1 = tabla_freq1[tabla_freq1['count']>3]
filtro1
# Out:
#             Geographical scope  count
# 0                       BRAZIL      9
# 1                    PUEBLA HQ      7
# 2                     BRAGANCA      6
# 3    LIPPSTADT 2 HQH & FES R&D      5
# 4  MLADA BOLESLAV FCM Bezdecin      5
# 5            PARIS TECH CENTER      5
# 6                  LIPPSTADT 1      4
# 7           MLADA BOLESLAV FIS      4
# 8                          NAO      4
# 9                       GOIANA      4

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index1 = filtro1.set_index('Geographical scope')
filtro_index1
# Out:
#                              count
# Geographical scope
# BRAZIL                           9
# PUEBLA HQ                        7
# BRAGANCA                         6
# LIPPSTADT 2 HQH & FES R&D        5
# MLADA BOLESLAV FCM Bezdecin      5
# PARIS TECH CENTER                5
# LIPPSTADT 1                      4
# MLADA BOLESLAV FIS               4
# NAO                              4
# GOIANA                           4

# %%
filtro_index1.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('Geographical Scope')
plt.xlabel('Scope')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #### **Project manager**

# %%
tabla_freq2 = df['Project manager'].value_counts().reset_index()
tabla_freq2
# Out:
#            Project manager  count
# 0          SOUZA Alexandre     15
# 1           BENAVENT Pablo     12
# 2             LOUBET Diana      9
# 3             SVARICEK Dan      9
# 4           MALTER Karsten      7
# ..                     ...    ...
# 105  AYEVA Djanwari Talata      1
# 106         WISCHMANN Imke      1
# 107            GOMEZ Tomas      1
# 108  GOIAN Floriana Simona      1
# 109             ZHANG Jack      1
#
# [110 rows x 2 columns]

# %%
# filtro con los valores más relevantes de la variable 
filtro2 = tabla_freq2[tabla_freq2['count']>3]
filtro2
# Out:
#      Project manager  count
# 0    SOUZA Alexandre     15
# 1     BENAVENT Pablo     12
# 2       LOUBET Diana      9
# 3       SVARICEK Dan      9
# 4     MALTER Karsten      7
# 5   LOURENCO Douglas      6
# 6      CAEIRO Helder      6
# 7      FENETRE Teddy      5
# 8      NITSCKIE Jade      5
# 9      ATTOF Mohamed      4
# 10        FRENZ Ingo      4
# 11          SANZ Ana      4

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index2 = filtro2.set_index('Project manager')
filtro_index2
# Out:
#                   count
# Project manager
# SOUZA Alexandre      15
# BENAVENT Pablo       12
# LOUBET Diana          9
# SVARICEK Dan          9
# MALTER Karsten        7
# LOURENCO Douglas      6
# CAEIRO Helder         6
# FENETRE Teddy         5
# NITSCKIE Jade         5
# ATTOF Mohamed         4
# FRENZ Ingo            4
# SANZ Ana              4

# %%
# realizamos gráfico de barras
filtro_index2.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('Project Manager')
plt.xlabel('Nombre')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #### **State**

# %%
tabla_freq3 = df['State'].value_counts().reset_index()
tabla_freq3
# Out:
#               State  count
# 0  Work in progress    213
# 1           Pending     11
# 2              Open      1

# %%
# filtro con los valores más relevantes de la variable 
filtro3 = tabla_freq3[tabla_freq3['count']>0]
filtro3
# Out:
#               State  count
# 0  Work in progress    213
# 1           Pending     11
# 2              Open      1

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index3 = filtro3.set_index('State')
filtro_index3
# Out:
#                   count
# State
# Work in progress    213
# Pending              11
# Open                  1

# %%
# realizamos gráfico de barras
filtro_index3.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('Project State')
plt.xlabel('Estado')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index3["count"].plot(kind = 'pie', figsize=(10,4), shadow = True, autopct="%0.1f %%", colormap ='Pastel1')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### **Projects Size**

# %%
tabla_freq4 = df['Project size'].value_counts().reset_index()
tabla_freq4
# Out:
#   Project size  count
# 0       MEDIUM     96
# 1        LARGE     71
# 2        SMALL     58

# %%
# filtro con los valores más relevantes de la variable 
filtro4 = tabla_freq4[tabla_freq4['count']>1]
filtro4
# Out:
#   Project size  count
# 0       MEDIUM     96
# 1        LARGE     71
# 2        SMALL     58

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index4 = filtro4.set_index('Project size')
filtro_index4
# Out:
#               count
# Project size
# MEDIUM           96
# LARGE            71
# SMALL            58

# %%
# realizamos gráfico de barras
filtro_index4.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid", rot=45)
plt. title('Project Size')
plt.xlabel('Tamaño')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filtro_index4["count"].plot(kind = 'pie', figsize=(10,4), shadow = True, autopct="%0.1f %%", colormap ='Pastel1')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### **Project Organization**

# %%
tabla_freq5 = df['Project organization'].value_counts().reset_index()
tabla_freq5
# Out:
#                                  Project organization  count
# 0        GIT/IT EMEA/MES & Digital Shopfloor projects     61
# 1   GIT/IT EMEA/Applications rollouts & Level 2 Su...     42
# 2   GIS/ITOP SAO./IT OP SAO shared/ITOP SAO FCS & ...     15
# 3   GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA MES ...     14
# 4        GIT/IT NAO/MES Applications & DT/Mexico MES      13
# 5                     GIT/IT NAO/NAO Applications/FCS      9
# 6   GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA Infr...      8
# 7                                          GIT/IT NAO      8
# 8                                    GIT/Applications      8
# 9            GIT/IT NAO/MES Applications & DT/US MES       6
# 10  GIS/ITOP SAO/IT OP SAO shared/ITOP SAO MES & S...      6
# 11          GIT/Applications/Engineering / R&D Domain      4
# 12  GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA FCS ...      4
# 13  GIT/Applications/Production Control & Logistic...      3
# 14  GIT/Applications/Business Services IT Function...      3
# 15                                     GIT/IT NAO/PMO      3
# 16  GIT/Applications/Applications Integration Serv...      2
# 17        GIS/APPLICATIONS./APPL PC&L, core JIT & TCO      2
# 18      GIT/Applications/Data Integration & Platforms      2
# 19  GIS/ITOP EMEA/IT OP EMEA Shared/ITOP EMEA Infr...      1
# 20            GIT/IT NAO/MES Applications & DT/MES DT      1
# 21  GIT/Applications/Manufacturing Execution Syste...      1
# 22  GIT/System Operations/Operations Services & Go...      1
# 23  GIT/IT NAO/IT Operations NAO/US Local IT Opera...      1
# 24      GIS/APPLICATIONS./APPL Core Business Services      1
# 25                          GIT/Central IT/Governance      1
# 26  GIT/IT NAO/IT Operations NAO/Regional L2 Infra...      1
# 27                       GIT/IT NAO/IT Operations NAO      1
# 28  GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA Regi...      1
# 29                   GIS/APPLICATIONS./APPL PMO & M&A      1
# 30  GIS/ITOP EMEA/IT OP EMEA Shared/ITOP EMEA MES ...      1

# %%
# filtro con los valores más relevantes de la variable 
filtro5 = tabla_freq5[tabla_freq5['count']>4]
filtro5
# Out:
#                                  Project organization  count
# 0        GIT/IT EMEA/MES & Digital Shopfloor projects     61
# 1   GIT/IT EMEA/Applications rollouts & Level 2 Su...     42
# 2   GIS/ITOP SAO./IT OP SAO shared/ITOP SAO FCS & ...     15
# 3   GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA MES ...     14
# 4        GIT/IT NAO/MES Applications & DT/Mexico MES      13
# 5                     GIT/IT NAO/NAO Applications/FCS      9
# 6   GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA Infr...      8
# 7                                          GIT/IT NAO      8
# 8                                    GIT/Applications      8
# 9            GIT/IT NAO/MES Applications & DT/US MES       6
# 10  GIS/ITOP SAO/IT OP SAO shared/ITOP SAO MES & S...      6

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index5 = filtro5.set_index('Project organization')
filtro_index5
# Out:
#                                                     count
# Project organization
# GIT/IT EMEA/MES & Digital Shopfloor projects           61
# GIT/IT EMEA/Applications rollouts & Level 2 Sup...     42
# GIS/ITOP SAO./IT OP SAO shared/ITOP SAO FCS & BPA.     15
# GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA MES &...     14
# GIT/IT NAO/MES Applications & DT/Mexico MES            13
# GIT/IT NAO/NAO Applications/FCS                         9
# GIS/ITOP ASIA/IT OP Asia Shared/ITOP ASIA Infra...      8
# GIT/IT NAO                                              8
# GIT/Applications                                        8
# GIT/IT NAO/MES Applications & DT/US MES                 6
# GIS/ITOP SAO/IT OP SAO shared/ITOP SAO MES & Sh...      6

# %%
# realizamos gráfico de barras
filtro_index5.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('Project Organization')
plt.xlabel('Organización')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #### **BG**

# %%
tabla_freq6 = df['BG'].value_counts().reset_index()
tabla_freq6
# Out:
#       BG  count
# 0    FIS     66
# 1    FCM     57
# 2    FAS     43
# 3  GROUP     29
# 4    FCE      8
# 5    FES      6
# 6    FLG      6
# 7    FLV      5
# 8    HQH      4
# 9    SAS      1

# %%
# filtro con los valores más relevantes de la variable 
filtro6 = tabla_freq6[tabla_freq6['count']>5]
filtro6
# Out:
#       BG  count
# 0    FIS     66
# 1    FCM     57
# 2    FAS     43
# 3  GROUP     29
# 4    FCE      8
# 5    FES      6
# 6    FLG      6

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index6 = filtro6.set_index('BG')
filtro_index6
# Out:
#        count
# BG
# FIS       66
# FCM       57
# FAS       43
# GROUP     29
# FCE        8
# FES        6
# FLG        6

# %%
# realizamos gráfico de barras
filtro_index6.plot(kind = 'bar', width = 0.8, figsize=(8,3), color = "orchid")
plt. title('BG')
plt.xlabel('Name')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #### **Project Health**

# %%
tabla_freq7 = df['Project Health'].value_counts().reset_index()
tabla_freq7
# Out:
#   Project Health  count
# 0          Green    166
# 1         Yellow     46
# 2            Red     13

# %%
# filtro con los valores más relevantes de la variable 
filtro7 = tabla_freq7[tabla_freq7['count']>1]
filtro7
# Out:
#   Project Health  count
# 0          Green    166
# 1         Yellow     46
# 2            Red     13

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index7 = filtro7.set_index('Project Health')
filtro_index7
# Out:
#                 count
# Project Health
# Green             166
# Yellow             46
# Red                13

# %%
filtro_index7["count"].plot(kind = 'pie', figsize=(10,4), shadow = True, autopct="%0.1f %%", colormap ='Pastel1')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### **On-Hold**

# %%
tabla_freq8 = df['On-hold'].value_counts().reset_index()
tabla_freq8
# Out:
#      On-hold  count
# 0      FALSO    176
# 1  VERDADERO     49

# %%
# filtro con los valores más relevantes de la variable 
filtro8 = tabla_freq8[tabla_freq8['count']>1]
filtro8
# Out:
#      On-hold  count
# 0      FALSO    176
# 1  VERDADERO     49

# %%
# ajusto el index el df (variables categoricas de tipo string y numericas)
filtro_index8 = filtro8.set_index('On-hold')
filtro_index8
# Out:
#            count
# On-hold
# FALSO        176
# VERDADERO     49

# %%
# realizamos gráfico de barras
filtro_index8["count"].plot(kind = 'pie', figsize=(10,4), shadow = True, autopct="%0.1f %%", colormap ='Pastel1')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### **Categorizar la variable "Percent complete" aplicando la regla de Sturges y desplegar en un gráfico las frecuencias de las categorías obtenidas**

# %%
df['Percent complete'].info() # Número total de la población "n"
n = 225
# Out:
# <class 'pandas.core.series.Series'>
# Index: 225 entries, 0 to 244
# Series name: Percent complete
# Non-Null Count  Dtype
# --------------  -----
# 225 non-null    float64
# dtypes: float64(1)
# memory usage: 3.5 KB

# %%
max = df['Percent complete'].max()
min = df['Percent complete'].min()
limites = [min, max]
limites
# Out:
# [np.float64(0.0), np.float64(99.92)]

# %%
R = max - min
R
# Out:
# np.float64(99.92)

# %%
ni = 1 + 3.32 * np.log10(n)
ni
# Out:
# np.float64(8.809245960129724)

# %% [markdown]
# Tomaremos el número redondeado como el correcto ni = 9

# %%
i = R / ni
i
# Out:
# np.float64(11.342628012912083)

# %%
intervalos = np.linspace(-0.1, 99.82, 10)
intervalos
# Out:
# array([-0.1       , 11.00222222, 22.10444444, 33.20666667, 44.30888889,
#        55.41111111, 66.51333333, 77.61555556, 88.71777778, 99.82      ])

# %%
categorias = [
    "Categoría 1 (0.0 - 11.1)",      
    "Categoría 2 (11.1 - 22.2)",     
    "Categoría 3 (22.2 - 33.3)",    
    "Categoría 4 (33.3 - 44.4)",    
    "Categoría 5 (44.4 - 55.6)",   
    "Categoría 6 (55.6 - 66.7)", 
    "Categoría 7 (66.7 - 77.8)",  
    "Categoría 8 (77.8 - 88.9)", 
    "Categoría 9 (88.9 - 99.8)"   
]

# %%
df['Percent complete'] = pd.cut(x = df['Percent complete'], bins = intervalos, labels = categorias)
df['Percent complete']
# Out:
# 0      Categoría 3 (22.2 - 33.3)
# 1      Categoría 5 (44.4 - 55.6)
# 2      Categoría 9 (88.9 - 99.8)
# 3      Categoría 2 (11.1 - 22.2)
# 4      Categoría 3 (22.2 - 33.3)
#                  ...
# 240     Categoría 1 (0.0 - 11.1)
# 241    Categoría 9 (88.9 - 99.8)
# 242     Categoría 1 (0.0 - 11.1)
# 243    Categoría 8 (77.8 - 88.9)
# 244     Categoría 1 (0.0 - 11.1)
# Name: Percent complete, Length: 225, dtype: category
# Categories (9, object): ['Categoría 1 (0.0 - 11.1)' < 'Categoría 2 (11.1 - 22.2)' < 'Categoría 3 (22.2 - 33.3)' < 'Categoría 4 (33.3 - 44.4)' ... 'Categoría 6 (55.6 - 66.7)' < 'Categoría 7 (66.7 - 77.8)' < 'Categoría 8 (77.8 - 88.9)' < 'Categoría 9 (88.9 - 99.8)']

# %%
tabla_freq9 = df['Percent complete'].value_counts().reset_index()
tabla_freq9
# Out:
#             Percent complete  count
# 0   Categoría 1 (0.0 - 11.1)     69
# 1  Categoría 9 (88.9 - 99.8)     41
# 2  Categoría 2 (11.1 - 22.2)     30
# 3  Categoría 3 (22.2 - 33.3)     22
# 4  Categoría 5 (44.4 - 55.6)     16
# 5  Categoría 4 (33.3 - 44.4)     15
# 6  Categoría 6 (55.6 - 66.7)     12
# 7  Categoría 8 (77.8 - 88.9)     12
# 8  Categoría 7 (66.7 - 77.8)      6

# %%
filtro9 = tabla_freq9[tabla_freq9['count']>0]
filtro9
# Out:
#             Percent complete  count
# 0   Categoría 1 (0.0 - 11.1)     69
# 1  Categoría 9 (88.9 - 99.8)     41
# 2  Categoría 2 (11.1 - 22.2)     30
# 3  Categoría 3 (22.2 - 33.3)     22
# 4  Categoría 5 (44.4 - 55.6)     16
# 5  Categoría 4 (33.3 - 44.4)     15
# 6  Categoría 6 (55.6 - 66.7)     12
# 7  Categoría 8 (77.8 - 88.9)     12
# 8  Categoría 7 (66.7 - 77.8)      6

# %%
filtro_index9 = filtro9.set_index('Percent complete')
filtro_index9
# Out:
#                            count
# Percent complete
# Categoría 1 (0.0 - 11.1)      69
# Categoría 9 (88.9 - 99.8)     41
# Categoría 2 (11.1 - 22.2)     30
# Categoría 3 (22.2 - 33.3)     22
# Categoría 5 (44.4 - 55.6)     16
# Categoría 4 (33.3 - 44.4)     15
# Categoría 6 (55.6 - 66.7)     12
# Categoría 8 (77.8 - 88.9)     12
# Categoría 7 (66.7 - 77.8)      6

# %%
filtro_index9.plot(kind = 'bar', width = 0.8, figsize = (10,4), color = "orchid", rot = 45)
plt. title('Percent Complete')
plt.xlabel('Categorías')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# La gráfica muestra una distribución descendente en la gestión de portfolios de proyectos.
#
# Vemos que hay muchos proyectos apenas empezando (78 en la primera categoría) y muy pocos que ya están casi listos o terminados (solo 12 en la última).
#
# Esto es normal es común que algunos proyectos se abandonen en el camino, otros tomen más tiempo del esperado, y solo unos cuantos logren terminarse correctamente.

# %% [markdown]
# ## Regresión lineal simple

# %% [markdown]
# Convertir las siguientes variables categóricas a numéricas de acuerdo a su jerarquía en frecuencias (Mayor Frecuencia = 1): Project Type, Geographical scope, Project manager, State, Project size, Project organization, BG, Project Health, On-hold. Obtener el dataframe que contenga únicamente a las columnas numéricas.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cols = ['Project Type', 'Geographical scope', 'Project manager', 'State', 'Project size', 'Project organization', 'BG', 'Project Health', 'On-hold']
for col in cols:
    df[col] = le.fit_transform(df[col])
    df[col] = df[col] + 1  # Incrementar en 1 para que la mayor frecuencia sea 1
df_num = df.select_dtypes(include=[np.number])
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 225 entries, 0 to 244
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Project Type          225 non-null    int64
#  1   Geographical scope    225 non-null    int64
#  2   Project manager       225 non-null    int64
#  3   State                 225 non-null    int64
#  4   Project size          225 non-null    int64
#  5   Project organization  225 non-null    int64
#  6   BG                    225 non-null    int64
#  7   Project Health        225 non-null    int64
#  8   On-hold               225 non-null    int64
# dtypes: int64(9)
# memory usage: 17.6 KB

# %%
print("\nTipos de datos en el dataframe convertido:")
print(df_num.dtypes)
# Out:
# Tipos de datos en el dataframe convertido:
# Project Type            int64
# Geographical scope      int64
# Project manager         int64
# State                   int64
# Project size            int64
# Project organization    int64
# BG                      int64
# Project Health          int64
# On-hold                 int64
# dtype: object

# %% [markdown]
# ### regresión lineal simple

# %%
##hacemos la matriz de correlación
print("\nMatriz de correlación:")
Corr_Factors = df_num.corr()
Corr_Factors
# Out:
# Matriz de correlación:
#                       Project Type  Geographical scope  Project manager  \
# Project Type              1.000000            0.116070        -0.150064
# Geographical scope        0.116070            1.000000         0.034761
# Project manager          -0.150064            0.034761         1.000000
# State                     0.141691            0.027901        -0.128892
# Project size              0.092805            0.009645         0.156898
# Project organization      0.217320            0.082748        -0.181224
# BG                        0.025657           -0.227722         0.061832
# Project Health            0.045141           -0.054766         0.021136
# On-hold                  -0.080656           -0.071808         0.070125
#
#                          State  Project size  Project organization        BG  \
# Project Type          0.141691      0.092805              0.217320  0.025657
# Geographical scope    0.027901      0.009645              0.082748 -0.227722
# Project manager      -0.128892      0.156898             -0.181224  0.061832
# State                 1.000000     -0.157928              0.120862 -0.084619
# Project size         -0.157928      1.000000              0.115164  0.004848
# Project organization  0.120862      0.115164              1.000000 -0.015659
# BG                   -0.084619      0.004848             -0.015659  1.000000
# Project Health       -0.085652     -0.086617              0.072307 -0.060117
# On-hold              -0.221179      0.111695             -0.129562  0.082848
#
#                       Project Health   On-hold
# Project Type                0.045141 -0.080656
# Geographical scope         -0.054766 -0.071808
# Project manager             0.021136  0.070125
# State                      -0.085652 -0.221179
# Project size               -0.086617  0.111695
# Project organization        0.072307 -0.129562
# BG                         -0.060117  0.082848
# Project Health              1.000000  0.227482
# On-hold                     0.227482  1.000000

# %%
##valores absolutos de la matriz de correlación
print("\n Absolutos de la Matriz de correlación:")
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#  Absolutos de la Matriz de correlación:
#                       Project Type  Geographical scope  Project manager  \
# Project Type              1.000000            0.116070         0.150064
# Geographical scope        0.116070            1.000000         0.034761
# Project manager           0.150064            0.034761         1.000000
# State                     0.141691            0.027901         0.128892
# Project size              0.092805            0.009645         0.156898
# Project organization      0.217320            0.082748         0.181224
# BG                        0.025657            0.227722         0.061832
# Project Health            0.045141            0.054766         0.021136
# On-hold                   0.080656            0.071808         0.070125
#
#                          State  Project size  Project organization        BG  \
# Project Type          0.141691      0.092805              0.217320  0.025657
# Geographical scope    0.027901      0.009645              0.082748  0.227722
# Project manager       0.128892      0.156898              0.181224  0.061832
# State                 1.000000      0.157928              0.120862  0.084619
# Project size          0.157928      1.000000              0.115164  0.004848
# Project organization  0.120862      0.115164              1.000000  0.015659
# BG                    0.084619      0.004848              0.015659  1.000000
# Project Health        0.085652      0.086617              0.072307  0.060117
# On-hold               0.221179      0.111695              0.129562  0.082848
#
#                       Project Health   On-hold
# Project Type                0.045141  0.080656
# Geographical scope          0.054766  0.071808
# Project manager             0.021136  0.070125
# State                       0.085652  0.221179
# Project size                0.086617  0.111695
# Project organization        0.072307  0.129562
# BG                          0.060117  0.082848
# Project Health              1.000000  0.227482
# On-hold                     0.227482  1.000000

# %%
### la grafica de calor 
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'coolwarm', annot=True)  
Heat_Map
# Out:
# <Axes: >

# %%
###ajustamos 
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'magma', annot=True, fmt=".2f")  
Heat_Map
# Out:
# <Axes: >

# %%
### tabla de los 5 pares 
top5 = pd.DataFrame({
    'Par de Variables': [
        'Geographical scope y BG',
        'On-hold y Project Health',
        'Project Type y Project organization',
        'State y On-hold',
        'Project manager y Project size'
    ],
    'Correlación': [0.23, 0.23, 0.22, 0.22, 0.16],
    'Interpretación': [
        'Presentan una correlación positiva débil, lo que indica que a mayor alcance geográfico del proyecto podría haber una ligera tendencia a cambios o variaciones en el indicador BG.',
        'Presentan una correlación positiva débil, lo que sugiere que los proyectos en espera tienden a tener una salud del proyecto similar.',
        'Presentan una correlación positiva débil, lo que indica que el tipo de proyecto podría estar relacionado con la organización del proyecto.',
        'Presentan una correlación positiva débil, lo que sugiere que el estado del proyecto podría estar relacionado con su estado de espera.',
        'Presentan una correlación positiva débil, lo que indica que el gerente del proyecto podría estar relacionado con el tamaño del proyecto.'
    ]
})
top5
# Out:
#                       Par de Variables  Correlación  \
# 0              Geographical scope y BG         0.23
# 1             On-hold y Project Health         0.23
# 2  Project Type y Project organization         0.22
# 3                      State y On-hold         0.22
# 4       Project manager y Project size         0.16
#
#                                       Interpretación
# 0  Presentan una correlación positiva débil, lo q...
# 1  Presentan una correlación positiva débil, lo q...
# 2  Presentan una correlación positiva débil, lo q...
# 3  Presentan una correlación positiva débil, lo q...
# 4  Presentan una correlación positiva débil, lo q...

# %% [markdown]
# ### regresión multiple

# %% [markdown]
# Crear el mejor modelo de regression lineal multiple para cada variable cuantitativa: (Project Type, Geographical scope, Project manager, State, Project size, Project organization, BG, Project Health, On-hold, Percent complete), y comparar los coeficientes obtenidos en estos modelos con respecto a los coeficientes obtenidos en el mapa de calor (lineales simples).

# %%
print("\n Absolutos de la Matriz de correlación:")
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#  Absolutos de la Matriz de correlación:
#                       Project Type  Geographical scope  Project manager  \
# Project Type              1.000000            0.116070         0.150064
# Geographical scope        0.116070            1.000000         0.034761
# Project manager           0.150064            0.034761         1.000000
# State                     0.141691            0.027901         0.128892
# Project size              0.092805            0.009645         0.156898
# Project organization      0.217320            0.082748         0.181224
# BG                        0.025657            0.227722         0.061832
# Project Health            0.045141            0.054766         0.021136
# On-hold                   0.080656            0.071808         0.070125
#
#                          State  Project size  Project organization        BG  \
# Project Type          0.141691      0.092805              0.217320  0.025657
# Geographical scope    0.027901      0.009645              0.082748  0.227722
# Project manager       0.128892      0.156898              0.181224  0.061832
# State                 1.000000      0.157928              0.120862  0.084619
# Project size          0.157928      1.000000              0.115164  0.004848
# Project organization  0.120862      0.115164              1.000000  0.015659
# BG                    0.084619      0.004848              0.015659  1.000000
# Project Health        0.085652      0.086617              0.072307  0.060117
# On-hold               0.221179      0.111695              0.129562  0.082848
#
#                       Project Health   On-hold
# Project Type                0.045141  0.080656
# Geographical scope          0.054766  0.071808
# Project manager             0.021136  0.070125
# State                       0.085652  0.221179
# Project size                0.086617  0.111695
# Project organization        0.072307  0.129562
# BG                          0.060117  0.082848
# Project Health              1.000000  0.227482
# On-hold                     0.227482  1.000000

# %% [markdown]
# ## Project type

# %%
Vars_Indep= df_num[['Project organization', 'State']]
Var_Dep= df_num['Project Type']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project organization', 'State'], dtype=object),
#  'n_features_in_': 2,
#  'coef_': array([0.09169835, 1.50307267]),
#  'rank_': 2,
#  'singular_': array([107.31620752,   3.74706454]),
#  'intercept_': np.float64(-0.9189415818728177)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['Project organization', 'State']])
y_pred
# Out:
# array([5.51594179, 5.51594179, 5.51594179, 5.51594179, 5.51594179,
#        4.14046652, 4.50725992, 5.51594179, 5.42424344, 4.23216487,
#        6.2495286 , 5.79103684, 6.2495286 , 5.51594179, 5.42424344,
#        5.42424344, 5.42424344, 4.32386322, 5.51594179, 6.2495286 ,
#        5.51594179, 5.51594179, 5.42424344, 5.42424344, 5.51594179,
#        5.51594179, 3.00418726, 4.50725992, 4.50725992, 4.50725992,
#        4.50725992, 4.50725992, 4.50725992, 4.50725992, 4.50725992,
#        5.05745003, 5.51594179, 5.42424344, 5.42424344, 4.14046652,
#        4.04876817, 4.04876817, 4.14046652, 3.95706982, 4.14046652,
#        5.42424344, 6.34122695, 5.88273519, 5.42424344, 4.04876817,
#        5.51594179, 5.42424344, 5.51594179, 5.42424344, 5.97443354,
#        5.24084673, 4.69065663, 4.59895828, 3.00418726, 4.59895828,
#        4.59895828, 5.51594179, 5.51594179, 5.05745003, 5.42424344,
#        5.42424344, 5.51594179, 5.51594179, 5.51594179, 4.14046652,
#        4.14046652, 3.95706982, 5.42424344, 3.95706982, 4.04876817,
#        5.51594179, 5.42424344, 5.51594179, 5.51594179, 5.42424344,
#        5.51594179, 5.51594179, 5.51594179, 5.51594179, 4.50725992,
#        3.73777407, 3.18758396, 4.69065663, 5.14914838, 3.18758396,
#        6.4329253 , 3.73777407, 4.69065663, 4.78235498, 4.87405333,
#        4.69065663, 4.87405333, 6.15783024, 6.15783024, 3.68197476,
#        5.42424344, 5.42424344, 5.05745003, 5.51594179, 5.51594179,
#        5.33254508, 5.42424344, 5.51594179, 5.51594179, 5.51594179,
#        5.51594179, 5.51594179, 5.51594179, 3.92117077, 5.51594179,
#        3.18758396, 6.06613189, 2.0513047 , 6.2495286 , 6.2495286 ,
#        5.69933849, 6.2495286 , 3.77367312, 5.51594179, 5.51594179,
#        5.51594179, 5.51594179, 5.51594179, 3.77367312, 5.51594179,
#        5.42424344, 5.51594179, 5.51594179, 5.51594179, 3.92117077,
#        5.42424344, 4.87405333, 5.42424344, 5.42424344, 4.69065663,
#        5.51594179, 5.42424344, 5.42424344, 5.51594179, 5.51594179,
#        5.42424344, 4.78235498, 5.42424344, 3.00418726, 4.59895828,
#        5.42424344, 6.06613189, 6.06613189, 6.15783024, 6.06613189,
#        6.06613189, 6.15783024, 6.2495286 , 6.06613189, 6.06613189,
#        5.60764014, 6.34122695, 5.60764014, 5.60764014, 5.60764014,
#        5.60764014, 5.60764014, 4.14046652, 4.04876817, 4.50725992,
#        3.00418726, 4.59895828, 6.06613189, 4.04876817, 3.95706982,
#        3.86537147, 5.51594179, 5.42424344, 5.51594179, 6.15783024,
#        6.06613189, 6.06613189, 6.06613189, 6.2495286 , 6.34122695,
#        6.06613189, 6.2495286 , 6.15783024, 5.42424344, 5.42424344,
#        5.51594179, 4.59895828, 4.04876817, 4.96575168, 4.14046652,
#        6.06613189, 5.42424344, 5.51594179, 5.51594179, 5.51594179,
#        5.51594179, 5.51594179, 5.42424344, 4.14046652, 5.51594179,
#        5.42424344, 4.96575168, 5.60764014, 5.60764014, 4.41556157,
#        5.42424344, 5.42424344, 5.51594179, 5.51594179, 5.42424344,
#        5.42424344, 5.42424344, 5.51594179, 5.51594179, 4.14046652,
#        4.14046652, 4.04876817, 4.14046652, 4.14046652, 4.14046652])

# %%
df_num.insert(0, 'PrediccionesTname0', y_pred)
df_num
# Out:
#      PrediccionesTname0  Project Type  Geographical scope  Project manager  \
# 0              5.515942             8                   1                8
# 1              5.515942             8                   2               59
# 2              5.515942             8                   3               96
# 3              5.515942             8                   3               59
# 4              5.515942             8                   4                8
# ..                  ...           ...                 ...              ...
# 240            4.140467             7                 123              104
# 241            4.048768             3                 123               16
# 242            4.140467             7                 124              104
# 243            4.140467             7                 125              104
# 244            4.140467             8                 125              110
#
#      State  Project size  Project organization  BG  Project Health  On-hold
# 0        3             3                    21   5               1        1
# 1        3             1                    21   3               3        2
# 2        3             2                    21   3               3        1
# 3        3             3                    21   3               1        2
# 4        3             2                    21   3               1        1
# ..     ...           ...                   ...  ..             ...      ...
# 240      3             2                     6   1               1        1
# 241      3             1                     5   1               1        1
# 242      3             2                     6   1               1        1
# 243      3             2                     6   1               1        1
# 244      3             3                     6   1               1        1
#
# [225 rows x 10 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                       Correlación simple  Coeficiente múltiple
# Project organization            0.217320              0.091698
# State                           0.141691              1.503073

# %%
sns.scatterplot(x='Project organization', y='Project Type', color="pink", data=df_num)
sns.scatterplot(x='Project organization', y='PrediccionesTname0', color="orange", data=df_num)
# Out:
# <Axes: xlabel='Project organization', ylabel='Project Type'>

# %% [markdown]
# ## Geographical scope

# %% [markdown]
# BG (0.23)
# Project organization (0.15 aprox.)
# Project Type (0.12 aprox.)

# %%
Vars_Indep= df_num[['BG', 'Project organization','Project Type']]
Var_Dep= df_num['Geographical scope']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['BG', 'Project organization', 'Project Type'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([-3.3880516 ,  0.26378869,  1.16296788]),
#  'rank_': 3,
#  'singular_': array([107.95336575,  47.02691478,  34.69034604]),
#  'intercept_': np.float64(65.02550818984997)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['BG', 'Project organization','Project Type']])
y_pred
# Out:
# array([62.9285557 , 69.7046589 , 69.7046589 , 69.7046589 , 69.7046589 ,
#        66.91079643, 41.72195016, 64.09152358, 54.52399186, 45.5824556 ,
#        63.67419327, 55.88170273, 52.54877466, 69.7046589 , 61.30009506,
#        61.30009506, 54.52399186, 62.7865023 , 66.21575527, 56.89809007,
#        69.7046589 , 69.7046589 , 61.30009506, 61.30009506, 69.7046589 ,
#        69.7046589 , 41.72195016, 41.72195016, 41.72195016, 41.72195016,
#        41.72195016, 41.72195016, 41.72195016, 41.72195016, 41.72195016,
#        71.67291502, 69.7046589 , 61.30009506, 61.30009506, 72.52393176,
#        42.72894247, 66.44530367, 58.97172535, 50.30337282, 73.68689964,
#        61.30009506, 62.97671815, 58.16887107, 54.52399186, 64.22021995,
#        75.31779423, 61.30009506, 64.09152358, 54.52399186, 65.41046703,
#        62.0363376 , 43.51334745, 60.2906688 , 51.88610496, 60.2906688 ,
#        60.2906688 , 62.9285557 , 64.09152358, 71.67291502, 44.35983706,
#        61.30009506, 64.09152358, 62.9285557 , 62.9285557 , 66.91079643,
#        65.74782856, 50.30337282, 68.07619826, 63.85557923, 66.44530367,
#        62.9285557 , 54.52399186, 62.9285557 , 69.7046589 , 61.30009506,
#        69.7046589 , 62.9285557 , 62.9285557 , 62.9285557 , 41.72195016,
#        51.87218279, 60.45360546, 53.67750226, 58.28364527, 60.45360546,
#        65.46559056, 55.26023439, 50.28945065, 50.55323934, 44.04092483,
#        53.67750226, 54.20507964, 71.55117973, 71.55117973, 39.34785195,
#        54.52399186, 54.52399186, 58.12070862, 64.09152358, 69.7046589 ,
#        50.87215157, 61.30009506, 69.7046589 , 69.7046589 , 69.7046589 ,
#        69.7046589 , 62.9285557 , 62.9285557 , 54.52399186, 62.9285557 ,
#        53.67750226, 64.51128784, 47.95655381, 70.45029647, 62.71292946,
#        55.61791404, 69.48903266, 63.32800185, 62.9285557 , 62.9285557 ,
#        62.9285557 , 62.9285557 , 62.9285557 , 63.32800185, 69.7046589 ,
#        61.30009506, 69.7046589 , 62.9285557 , 62.9285557 , 64.68814666,
#        64.68814666, 67.75728604, 64.68814666, 64.68814666, 50.28945065,
#        77.64372998, 68.07619826, 68.07619826, 69.7046589 , 69.7046589 ,
#        44.35983706, 47.16518774, 61.30009506, 65.43831137, 73.84287521,
#        54.52399186, 78.06349424, 64.51128784, 64.77507653, 64.51128784,
#        64.51128784, 64.77507653, 56.89809007, 64.51128784, 64.51128784,
#        55.35412535, 46.99772396, 55.35412535, 49.53928595, 49.53928595,
#        55.35412535, 55.35412535, 72.52393176, 37.11580714, 65.43831137,
#        65.43831137, 73.84287521, 71.28739104, 66.44530367, 57.07947603,
#        50.03958413, 68.54169102, 68.07619826, 72.99185847, 64.77507653,
#        71.28739104, 71.28739104, 71.28739104, 67.06224487, 73.14087296,
#        78.06349424, 70.45029647, 64.77507653, 68.07619826, 68.07619826,
#        72.99185847, 73.84287521, 52.89309727, 51.08081672, 65.74782856,
#        71.28739104, 44.35983706, 62.9285557 , 62.9285557 , 59.43965207,
#        69.7046589 , 70.86762678, 61.30009506, 58.97172535, 69.7046589 ,
#        61.30009506, 61.24497153, 51.96607374, 51.96607374, 59.76309142,
#        54.52399186, 61.30009506, 76.48076211, 76.48076211, 68.07619826,
#        68.07619826, 68.07619826, 77.64372998, 72.99185847, 60.13469323,
#        71.36096388, 66.44530367, 71.36096388, 71.36096388, 72.52393176])

# %%
df_num.insert(0, 'PrediccionesGeographical scope', y_pred)
df_num
# Out:
#      PrediccionesGeographical scope  PrediccionesTname0  Project Type  \
# 0                         62.928556            5.515942             8
# 1                         69.704659            5.515942             8
# 2                         69.704659            5.515942             8
# 3                         69.704659            5.515942             8
# 4                         69.704659            5.515942             8
# ..                              ...                 ...           ...
# 240                       71.360964            4.140467             7
# 241                       66.445304            4.048768             3
# 242                       71.360964            4.140467             7
# 243                       71.360964            4.140467             7
# 244                       72.523932            4.140467             8
#
#      Geographical scope  Project manager  State  Project size  \
# 0                     1                8      3             3
# 1                     2               59      3             1
# 2                     3               96      3             2
# 3                     3               59      3             3
# 4                     4                8      3             2
# ..                  ...              ...    ...           ...
# 240                 123              104      3             2
# 241                 123               16      3             1
# 242                 124              104      3             2
# 243                 125              104      3             2
# 244                 125              110      3             3
#
#      Project organization  BG  Project Health  On-hold
# 0                      21   5               1        1
# 1                      21   3               3        2
# 2                      21   3               3        1
# 3                      21   3               1        2
# 4                      21   3               1        1
# ..                    ...  ..             ...      ...
# 240                     6   1               1        1
# 241                     5   1               1        1
# 242                     6   1               1        1
# 243                     6   1               1        1
# 244                     6   1               1        1
#
# [225 rows x 11 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                       Correlación simple  Coeficiente múltiple
# BG                             -0.227722             -3.388052
# Project organization            0.082748              0.263789
# Project Type                    0.116070              1.162968

# %%
sns.scatterplot(x='BG', y='Geographical scope', color="pink", data=df_num)
sns.scatterplot(x='BG', y='PrediccionesGeographical scope', color="orange", data=df_num)
# Out:
# <Axes: xlabel='BG', ylabel='Geographical scope'>

# %% [markdown]
# ## Project manager

# %% [markdown]
# Project size (0.16)
# State (0.12 aprox.)
# Project Type (0.10 aprox.)

# %%
Vars_Indep= df_num[['State', 'Project size','Project Type']]
Var_Dep= df_num['Project manager']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['State', 'Project size', 'Project Type'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([-10.21176597,   6.54512589,  -1.48156323]),
#  'rank_': 3,
#  'singular_': array([48.45216074, 11.29405828,  3.67289321]),
#  'intercept_': np.float64(81.02941901248344)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['State', 'Project size','Project Type']])
y_pred
# Out:
# array([58.17699293, 45.08674115, 51.63186704, 58.17699293, 51.63186704,
#        43.60517792, 62.00280966, 43.60517792, 55.45768377, 49.53143084,
#        62.00280966, 42.12361469, 61.1401194 , 45.08674115, 62.00280966,
#        62.00280966, 62.00280966, 62.62168263, 62.62168263, 55.45768377,
#        45.08674115, 45.08674115, 62.00280966, 62.00280966, 58.17699293,
#        51.63186704, 78.75970152, 62.00280966, 62.00280966, 62.00280966,
#        62.00280966, 55.45768377, 62.00280966, 62.00280966, 62.00280966,
#        49.53143084, 58.17699293, 62.00280966, 62.00280966, 58.17699293,
#        52.49455731, 52.49455731, 58.17699293, 62.00280966, 43.60517792,
#        62.00280966, 48.04986761, 52.49455731, 62.00280966, 51.01299408,
#        53.11343027, 62.00280966, 43.60517792, 62.00280966, 43.60517792,
#        62.62168263, 56.07655674, 58.17699293, 78.75970152, 51.63186704,
#        58.17699293, 58.17699293, 56.6954297 , 56.07655674, 62.00280966,
#        62.00280966, 56.6954297 , 58.17699293, 45.08674115, 43.60517792,
#        45.08674115, 55.45768377, 62.00280966, 55.45768377, 52.49455731,
#        45.08674115, 62.00280966, 58.17699293, 45.08674115, 62.00280966,
#        51.63186704, 58.17699293, 51.63186704, 45.08674115, 55.45768377,
#        66.2883227 , 66.2883227 , 62.62168263, 67.06637232, 72.8334486 ,
#        62.62168263, 72.8334486 , 56.07655674, 62.62168263, 56.07655674,
#        62.62168263, 62.62168263, 58.17699293, 58.17699293, 55.45768377,
#        62.00280966, 55.45768377, 49.53143084, 43.60517792, 58.17699293,
#        55.45768377, 62.00280966, 45.08674115, 58.17699293, 51.63186704,
#        58.17699293, 51.63186704, 45.08674115, 72.21457563, 45.08674115,
#        72.8334486 , 58.17699293, 76.50008867, 55.45768377, 48.04986761,
#        42.12361469, 48.04986761, 55.45768377, 45.08674115, 45.08674115,
#        45.08674115, 58.17699293, 45.08674115, 55.45768377, 45.08674115,
#        62.00280966, 58.17699293, 45.08674115, 51.63186704, 72.21457563,
#        62.00280966, 56.07655674, 62.00280966, 62.00280966, 62.62168263,
#        43.60517792, 62.00280966, 62.00280966, 58.17699293, 58.17699293,
#        62.00280966, 56.07655674, 62.00280966, 72.21457563, 58.17699293,
#        62.00280966, 51.63186704, 58.17699293, 51.63186704, 58.17699293,
#        51.63186704, 51.63186704, 55.45768377, 51.63186704, 58.17699293,
#        55.21386647, 68.54793556, 48.66874058, 49.53143084, 49.53143084,
#        48.66874058, 48.66874058, 51.63186704, 51.01299408, 55.45768377,
#        78.75970152, 58.17699293, 51.63186704, 52.49455731, 62.00280966,
#        62.00280966, 53.11343027, 62.00280966, 62.62168263, 51.63186704,
#        58.17699293, 51.63186704, 51.63186704, 55.45768377, 48.04986761,
#        58.17699293, 55.45768377, 58.17699293, 55.45768377, 62.00280966,
#        62.62168263, 51.63186704, 52.49455731, 62.62168263, 45.08674115,
#        58.17699293, 62.00280966, 45.08674115, 51.63186704, 56.07655674,
#        58.17699293, 43.60517792, 62.00280966, 45.08674115, 51.63186704,
#        62.00280966, 56.07655674, 42.12361469, 48.66874058, 51.63186704,
#        62.00280966, 62.00280966, 45.08674115, 51.63186704, 62.00280966,
#        62.00280966, 62.00280966, 43.60517792, 62.62168263, 43.60517792,
#        53.11343027, 52.49455731, 53.11343027, 53.11343027, 58.17699293])

# %%
df_num.insert(0, 'PrediccionesProject manager', y_pred)
df_num
# Out:
#      PrediccionesProject manager  PrediccionesGeographical scope  \
# 0                      58.176993                       62.928556
# 1                      45.086741                       69.704659
# 2                      51.631867                       69.704659
# 3                      58.176993                       69.704659
# 4                      51.631867                       69.704659
# ..                           ...                             ...
# 240                    53.113430                       71.360964
# 241                    52.494557                       66.445304
# 242                    53.113430                       71.360964
# 243                    53.113430                       71.360964
# 244                    58.176993                       72.523932
#
#      PrediccionesTname0  Project Type  Geographical scope  Project manager  \
# 0              5.515942             8                   1                8
# 1              5.515942             8                   2               59
# 2              5.515942             8                   3               96
# 3              5.515942             8                   3               59
# 4              5.515942             8                   4                8
# ..                  ...           ...                 ...              ...
# 240            4.140467             7                 123              104
# 241            4.048768             3                 123               16
# 242            4.140467             7                 124              104
# 243            4.140467             7                 125              104
# 244            4.140467             8                 125              110
#
#      State  Project size  Project organization  BG  Project Health  On-hold
# 0        3             3                    21   5               1        1
# 1        3             1                    21   3               3        2
# 2        3             2                    21   3               3        1
# 3        3             3                    21   3               1        2
# 4        3             2                    21   3               1        1
# ..     ...           ...                   ...  ..             ...      ...
# 240      3             2                     6   1               1        1
# 241      3             1                     5   1               1        1
# 242      3             2                     6   1               1        1
# 243      3             2                     6   1               1        1
# 244      3             3                     6   1               1        1
#
# [225 rows x 12 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#               Correlación simple  Coeficiente múltiple
# State                  -0.128892            -10.211766
# Project size            0.156898              6.545126
# Project Type           -0.150064             -1.481563

# %%
sns.scatterplot(x='Project size', y='Project manager', color="pink", data=df_num)
sns.scatterplot(x='Project size', y='PrediccionesProject manager', color="orange", data=df_num)
# Out:
# <Axes: xlabel='Project size', ylabel='Project manager'>

# %% [markdown]
# ### State

# %% [markdown]
# On-hold (0.22)
# Project organization (0.15 aprox.)
# Project Type (0.12 aprox.)

# %%
Vars_Indep= df_num[['On-hold', 'Project organization','Project Type']]
Var_Dep= df_num['State']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['On-hold', 'Project organization', 'Project Type'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([-0.12386837,  0.00248493,  0.00856874]),
#  'rank_': 3,
#  'singular_': array([107.95524644,  47.00151772,   6.12951766]),
#  'intercept_': np.float64(3.0044360284928624)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['On-hold', 'Project organization','Project Type']])
y_pred
# Out:
# array([3.00130104, 2.87743267, 3.00130104, 2.87743267, 3.00130104,
#        2.97259586, 2.7901173 , 3.00986978, 2.93883495, 2.94080584,
#        2.83733093, 3.0258933 , 3.00404299, 3.00130104, 2.93883495,
#        2.93883495, 2.93883495, 2.94329077, 2.97559483, 2.9611993 ,
#        2.87743267, 3.00130104, 2.93883495, 2.93883495, 2.87743267,
#        3.00130104, 2.7901173 , 2.91398567, 2.7901173 , 2.91398567,
#        2.91398567, 2.91398567, 2.7901173 , 2.7901173 , 2.7901173 ,
#        2.96317019, 3.00130104, 2.93883495, 2.93883495, 2.96402713,
#        2.91869851, 2.91869851, 2.96402713, 2.77520773, 2.97259586,
#        2.81496658, 3.00652792, 2.96839707, 2.93883495, 2.80339887,
#        2.99273231, 2.93883495, 3.00986978, 2.93883495, 2.89842605,
#        2.96814005, 2.82936211, 2.97645176, 2.7901173 , 2.97645176,
#        2.97645176, 3.00130104, 3.00986978, 2.96317019, 2.93883495,
#        2.93883495, 3.00986978, 3.00130104, 3.00130104, 2.97259586,
#        2.96402713, 2.89907611, 2.93883495, 2.89907611, 2.91869851,
#        3.00130104, 2.93883495, 2.87743267, 3.00130104, 2.93883495,
#        3.00130104, 2.87743267, 3.00130104, 3.00130104, 2.91398567,
#        2.84427167, 2.82936211, 2.95323048, 2.93994891, 2.82936211,
#        3.00044411, 2.84427167, 2.82936211, 2.95571541, 2.95820034,
#        2.82936211, 2.95820034, 3.01869554, 3.01869554, 2.76775295,
#        2.93883495, 2.93883495, 2.96317019, 2.88600141, 3.00130104,
#        2.93635002, 2.93883495, 2.87743267, 2.87743267, 3.00130104,
#        3.00130104, 3.00130104, 3.00130104, 2.93883495, 3.00130104,
#        2.82936211, 3.01621061, 2.96317019, 2.9611993 , 3.00404299,
#        3.02340838, 3.00404299, 2.77023788, 3.00130104, 3.00130104,
#        3.00130104, 3.00130104, 3.00130104, 2.77023788, 3.00130104,
#        2.93883495, 2.87743267, 3.00130104, 3.00130104, 2.93883495,
#        2.93883495, 2.95820034, 2.93883495, 2.93883495, 2.95323048,
#        2.88600141, 2.93883495, 2.93883495, 3.00130104, 3.00130104,
#        2.93883495, 2.95571541, 2.93883495, 2.91398567, 2.97645176,
#        2.93883495, 3.01621061, 3.01621061, 3.01869554, 3.01621061,
#        2.89234224, 3.01869554, 2.9611993 , 2.89234224, 3.01621061,
#        3.02092345, 2.96368423, 3.02092345, 2.97807976, 2.97807976,
#        3.02092345, 3.02092345, 2.96402713, 2.80339887, 2.91398567,
#        2.7901173 , 2.97645176, 3.01621061, 2.91869851, 2.89907611,
#        2.7727228 , 2.86886393, 2.93883495, 2.97559483, 3.01869554,
#        2.89234224, 3.01621061, 3.01621061, 2.83733093, 3.00652792,
#        2.89234224, 2.9611993 , 3.01869554, 2.93883495, 2.93883495,
#        2.85172646, 2.97645176, 2.91869851, 2.83681689, 2.96402713,
#        3.01621061, 2.81496658, 3.00130104, 3.00130104, 2.97559483,
#        3.00130104, 3.00986978, 2.93883495, 2.96402713, 3.00130104,
#        2.93883495, 2.96068526, 3.02092345, 3.02092345, 2.97148191,
#        2.93883495, 2.93883495, 3.00130104, 3.00130104, 2.93883495,
#        2.93883495, 2.81496658, 2.88600141, 2.85172646, 2.97259586,
#        2.95545839, 2.91869851, 2.95545839, 2.95545839, 2.96402713])

# %%
df_num.insert(0, 'PrediccionesState', y_pred)
df_num
# Out:
#      PrediccionesState  PrediccionesProject manager  \
# 0             3.001301                    58.176993
# 1             2.877433                    45.086741
# 2             3.001301                    51.631867
# 3             2.877433                    58.176993
# 4             3.001301                    51.631867
# ..                 ...                          ...
# 240           2.955458                    53.113430
# 241           2.918699                    52.494557
# 242           2.955458                    53.113430
# 243           2.955458                    53.113430
# 244           2.964027                    58.176993
#
#      PrediccionesGeographical scope  PrediccionesTname0  Project Type  \
# 0                         62.928556            5.515942             8
# 1                         69.704659            5.515942             8
# 2                         69.704659            5.515942             8
# 3                         69.704659            5.515942             8
# 4                         69.704659            5.515942             8
# ..                              ...                 ...           ...
# 240                       71.360964            4.140467             7
# 241                       66.445304            4.048768             3
# 242                       71.360964            4.140467             7
# 243                       71.360964            4.140467             7
# 244                       72.523932            4.140467             8
#
#      Geographical scope  Project manager  State  Project size  \
# 0                     1                8      3             3
# 1                     2               59      3             1
# 2                     3               96      3             2
# 3                     3               59      3             3
# 4                     4                8      3             2
# ..                  ...              ...    ...           ...
# 240                 123              104      3             2
# 241                 123               16      3             1
# 242                 124              104      3             2
# 243                 125              104      3             2
# 244                 125              110      3             3
#
#      Project organization  BG  Project Health  On-hold
# 0                      21   5               1        1
# 1                      21   3               3        2
# 2                      21   3               3        1
# 3                      21   3               1        2
# 4                      21   3               1        1
# ..                    ...  ..             ...      ...
# 240                     6   1               1        1
# 241                     5   1               1        1
# 242                     6   1               1        1
# 243                     6   1               1        1
# 244                     6   1               1        1
#
# [225 rows x 13 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                       Correlación simple  Coeficiente múltiple
# On-hold                        -0.221179             -0.123868
# Project organization            0.120862              0.002485
# Project Type                    0.141691              0.008569

# %%
sns.scatterplot(x='On-hold', y='State', color="pink", data=df_num)
sns.scatterplot(x='On-hold', y='PrediccionesState', color="orange", data=df_num)
# Out:
# <Axes: xlabel='On-hold', ylabel='State'>

# %% [markdown]
# ## Project size

# %% [markdown]
# Project manager (0.16)
# Project organization (0.14 aprox.)
# Project Type (0.10 aprox.)

# %%
Vars_Indep= df_num[['Project manager', 'Project organization','Project Type']]
Var_Dep= df_num['Project size']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project manager', 'Project organization', 'Project Type'],
#        dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.00469955, 0.01372354, 0.02191539]),
#  'rank_': 3,
#  'singular_': array([469.25471978, 105.95094194,  46.7331583 ]),
#  'intercept_': np.float64(1.3199961616198328)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['Project manager', 'Project organization','Project Type']])
y_pred
# Out:
# array([1.82111002, 2.06078709, 2.23467046, 2.06078709, 1.82111002,
#        1.8251543 , 1.90210649, 2.14849618, 1.79026574, 1.7418172 ,
#        2.19575063, 2.04709793, 2.23953386, 1.91510103, 1.9735482 ,
#        1.76676799, 1.8795572 , 1.56755873, 2.1689243 , 2.09236053,
#        1.82111002, 1.82111002, 1.79966484, 1.86545855, 1.85400688,
#        1.82111002, 1.90210649, 1.90210649, 1.90210649, 1.90210649,
#        1.90210649, 1.90210649, 1.90210649, 1.90210649, 1.90210649,
#        1.74314076, 2.23467046, 1.93125225, 1.93125225, 2.07111329,
#        1.67523889, 1.55775014, 2.06171419, 1.56598953, 1.92854441,
#        1.68217608, 2.2532574 , 1.73822996, 2.05814011, 1.9791273 ,
#        1.87438744, 1.9735482 , 1.93701642, 1.9735482 , 2.12782243,
#        1.94447121, 2.05481153, 1.89065483, 1.90210649, 1.89065483,
#        1.89065483, 2.16887675, 2.19079214, 1.74314076, 1.67277698,
#        1.76206844, 2.24248719, 2.04198889, 2.04198889, 1.67946824,
#        1.60115825, 1.9090567 , 2.05814011, 1.56598953, 1.67523889,
#        1.79761227, 1.75736889, 1.79761227, 1.91510103, 1.82316259,
#        1.91510103, 2.22057181, 2.04198889, 2.04198889, 1.90210649,
#        2.07135907, 1.86212996, 1.88562771, 1.93079521, 1.74934075,
#        2.01478759, 2.17474918, 1.91382501, 1.91814946, 1.64050087,
#        1.86212996, 2.05406131, 2.30723749, 1.96417032, 1.45432565,
#        1.99704596, 1.70567383, 1.77133806, 1.81952766, 1.89630283,
#        1.72014759, 1.82316259, 2.22057181, 2.06078709, 2.1265808 ,
#        2.22057181, 2.04198889, 2.22057181, 2.05814011, 2.22057181,
#        1.88562771, 2.07733464, 1.83713177, 1.84798391, 1.95756084,
#        1.85949103, 1.95756084, 1.5714393 , 1.85400688, 1.85400688,
#        1.85400688, 1.82111002, 1.82111002, 1.50564559, 1.82111002,
#        1.99704596, 1.82111002, 1.85400688, 1.85400688, 1.99704596,
#        1.75736889, 2.025864  , 1.66337788, 1.66337788, 1.91382501,
#        2.24248719, 2.01584416, 1.9829473 , 2.22057181, 2.22057181,
#        1.97824775, 1.65967419, 1.93125225, 1.90210649, 1.89065483,
#        1.93125225, 2.10553194, 2.10553194, 2.11455593, 2.23711935,
#        2.10553194, 2.11455593, 2.14875513, 2.10553194, 2.2418189 ,
#        2.0713459 , 1.88050565, 2.12304096, 2.07925773, 2.20614559,
#        2.17943556, 1.88336389, 2.06171419, 1.69715428, 1.90210649,
#        1.90210649, 1.89065483, 2.10553194, 1.7598308 , 1.843263  ,
#        1.57576374, 1.87438744, 1.91245405, 1.73186611, 2.18034963,
#        2.10553194, 2.10553194, 2.10553194, 2.20514973, 2.33314976,
#        2.10553194, 2.06416322, 2.18034963, 1.67747653, 1.86545855,
#        1.99034138, 1.89065483, 1.95721192, 2.04898665, 2.06171419,
#        2.28411485, 1.93125225, 2.05608754, 1.82111002, 2.10313059,
#        1.82111002, 1.84302541, 1.91245405, 2.08521194, 1.89630283,
#        1.8795572 , 2.04898665, 2.0055522 , 2.12774051, 1.87730639,
#        2.09573651, 1.79966484, 2.16887675, 1.89630283, 1.81376349,
#        1.64927923, 1.76206844, 2.06390428, 1.99034138, 1.92854441,
#        2.04449835, 1.52955283, 2.04449835, 2.04449835, 2.09461104])

# %%
df_num.insert(0, 'PrediccionesProjectSize', y_pred)
df_num
# Out:
#      PrediccionesProjectSize  PrediccionesState  PrediccionesProject manager  \
# 0                   1.821110           3.001301                    58.176993
# 1                   2.060787           2.877433                    45.086741
# 2                   2.234670           3.001301                    51.631867
# 3                   2.060787           2.877433                    58.176993
# 4                   1.821110           3.001301                    51.631867
# ..                       ...                ...                          ...
# 240                 2.044498           2.955458                    53.113430
# 241                 1.529553           2.918699                    52.494557
# 242                 2.044498           2.955458                    53.113430
# 243                 2.044498           2.955458                    53.113430
# 244                 2.094611           2.964027                    58.176993
#
#      PrediccionesGeographical scope  PrediccionesTname0  Project Type  \
# 0                         62.928556            5.515942             8
# 1                         69.704659            5.515942             8
# 2                         69.704659            5.515942             8
# 3                         69.704659            5.515942             8
# 4                         69.704659            5.515942             8
# ..                              ...                 ...           ...
# 240                       71.360964            4.140467             7
# 241                       66.445304            4.048768             3
# 242                       71.360964            4.140467             7
# 243                       71.360964            4.140467             7
# 244                       72.523932            4.140467             8
#
#      Geographical scope  Project manager  State  Project size  \
# 0                     1                8      3             3
# 1                     2               59      3             1
# 2                     3               96      3             2
# 3                     3               59      3             3
# 4                     4                8      3             2
# ..                  ...              ...    ...           ...
# 240                 123              104      3             2
# 241                 123               16      3             1
# 242                 124              104      3             2
# 243                 125              104      3             2
# 244                 125              110      3             3
#
#      Project organization  BG  Project Health  On-hold
# 0                      21   5               1        1
# 1                      21   3               3        2
# 2                      21   3               3        1
# 3                      21   3               1        2
# 4                      21   3               1        1
# ..                    ...  ..             ...      ...
# 240                     6   1               1        1
# 241                     5   1               1        1
# 242                     6   1               1        1
# 243                     6   1               1        1
# 244                     6   1               1        1
#
# [225 rows x 14 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                       Correlación simple  Coeficiente múltiple
# Project manager                 0.156898              0.004700
# Project organization            0.115164              0.013724
# Project Type                    0.092805              0.021915

# %%
sns.scatterplot(x='Project manager', y='Project size', color="pink", data=df_num)
sns.scatterplot(x='Project manager', y='PrediccionesProjectSize', color="orange", data=df_num)
# Out:
# <Axes: xlabel='Project manager', ylabel='Project size'>

# %% [markdown]
# ## Project organization

# %% [markdown]
# Project Type (0.22)
# Geographical scope (0.15)
# Project size (0.14)

# %%
Vars_Indep= df_num[['Geographical scope', 'Project size','Project Type']]
Var_Dep= df_num['Project organization']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Geographical scope', 'Project size', 'Project Type'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.01223722, 0.90864658, 0.4467459 ]),
#  'rank_': 3,
#  'singular_': array([512.34180358,  48.11888136,  11.27300631]),
#  'intercept_': np.float64(13.101053459308886)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['Geographical scope', 'Project size','Project Type']])
y_pred
# Out:
# array([19.41319765, 17.6081417 , 18.52902551, 19.43767209, 18.54126273,
#        18.09159927, 15.43851587, 18.11607372, 14.54210651, 16.34132734,
#        15.47522754, 18.58729407, 18.61760363, 17.70603949, 15.49970198,
#        15.49970198, 15.51193921, 18.21980662, 18.23204384, 14.64000429,
#        17.77946283, 17.77946283, 15.5608881 , 15.5608881 , 19.596756  ,
#        18.68810941, 16.48177191, 15.57312532, 15.57312532, 15.57312532,
#        15.57312532, 14.66447874, 15.57312532, 15.57312532, 15.57312532,
#        16.46369957, 19.63346767, 15.59759977, 15.59759977, 19.64570489,
#        15.60691944, 15.61915666, 19.68241656, 15.65878589, 18.33634374,
#        15.68326034, 17.02058048, 15.68034278, 15.70773478, 16.15156313,
#        18.41268464, 15.74444645, 18.42200431, 15.75668368, 18.43424153,
#        18.47678831, 17.58037895, 19.84150046, 16.71427915, 18.93285388,
#        19.84150046, 19.85373769, 20.30048359, 17.61709062, 15.83010702,
#        15.84234424, 20.33719526, 19.89044936, 18.07315619, 18.53213932,
#        18.09763064, 14.98264655, 15.90353036, 15.007121  , 15.91285002,
#        18.15881676, 15.94024203, 19.97610992, 18.17105398, 15.95247925,
#        19.07970056, 20.00058437, 19.09193779, 18.1832912 , 15.06830711,
#        17.77617453, 17.77617453, 18.68482111, 17.3445834 , 18.69705833,
#        18.69705833, 18.69705833, 17.80064897, 18.70929556, 17.80064897,
#        18.70929556, 18.70929556, 20.06177049, 20.06177049, 15.12949323,
#        16.05037704, 15.14173045, 16.92871406, 18.72793489, 20.11071938,
#        15.17844212, 16.09932593, 18.31790066, 20.13519383, 19.22654724,
#        20.13519383, 19.23878447, 18.33013788, 16.11156315, 18.33013788,
#        18.81943057, 20.1719055 , 17.93525843, 15.25186546, 17.48559497,
#        19.27257858, 17.48559497, 15.26410269, 18.40356122, 18.40356122,
#        18.40356122, 20.23309161, 18.41579845, 15.30081436, 18.44027289,
#        16.22169816, 20.25756606, 18.45251012, 19.3611567 , 16.24617261,
#        16.24617261, 18.03315622, 16.24617261, 16.24617261, 18.95404002,
#        18.93596769, 16.27064706, 16.27064706, 20.31875218, 20.31875218,
#        16.29512151, 18.08210511, 16.30735873, 16.31959595, 20.35546385,
#        16.33183318, 19.47129171, 20.39217552, 19.48352893, 20.40441274,
#        19.49576616, 19.49576616, 15.47213549, 19.5202406 , 20.42888719,
#        21.33461621, 17.3139031 , 20.42596963, 17.28359354, 17.28359354,
#        20.42596963, 20.42596963, 19.54471505, 16.86132208, 15.5333216 ,
#        17.35061477, 20.47783608, 19.58142672, 16.45128785, 16.47867986,
#        16.49091708, 19.18362971, 16.51539153, 19.21102172, 19.65485006,
#        20.57573387, 19.66708728, 19.66708728, 15.64345661, 17.87718612,
#        20.60020831, 15.66793106, 20.62468276, 15.69240551, 16.61328931,
#        19.3089195 , 19.75274785, 16.62260898, 19.34563117, 18.88081294,
#        20.71034333, 16.68671265, 18.91752461, 19.82617119, 18.48593348,
#        20.747055  , 19.37650773, 16.7111871 , 18.94199905, 19.86288286,
#        16.73566155, 18.53488238, 19.87220253, 20.78084911, 19.89959453,
#        16.78461044, 16.79684766, 19.02765962, 19.94854342, 16.82132211,
#        16.82132211, 16.83355933, 19.51111719, 19.54142675, 19.52335441,
#        19.55074641, 16.85511623, 19.56298364, 19.57522086, 20.93061335])

# %%
df_num.insert(0, 'PrediccionesProjectorg', y_pred)
df_num
# Out:
#      PrediccionesProjectorg  PrediccionesProjectSize  PrediccionesState  \
# 0                 19.413198                 1.821110           3.001301
# 1                 17.608142                 2.060787           2.877433
# 2                 18.529026                 2.234670           3.001301
# 3                 19.437672                 2.060787           2.877433
# 4                 18.541263                 1.821110           3.001301
# ..                      ...                      ...                ...
# 240               19.550746                 2.044498           2.955458
# 241               16.855116                 1.529553           2.918699
# 242               19.562984                 2.044498           2.955458
# 243               19.575221                 2.044498           2.955458
# 244               20.930613                 2.094611           2.964027
#
#      PrediccionesProject manager  PrediccionesGeographical scope  \
# 0                      58.176993                       62.928556
# 1                      45.086741                       69.704659
# 2                      51.631867                       69.704659
# 3                      58.176993                       69.704659
# 4                      51.631867                       69.704659
# ..                           ...                             ...
# 240                    53.113430                       71.360964
# 241                    52.494557                       66.445304
# 242                    53.113430                       71.360964
# 243                    53.113430                       71.360964
# 244                    58.176993                       72.523932
#
#      PrediccionesTname0  Project Type  Geographical scope  Project manager  \
# 0              5.515942             8                   1                8
# 1              5.515942             8                   2               59
# 2              5.515942             8                   3               96
# 3              5.515942             8                   3               59
# 4              5.515942             8                   4                8
# ..                  ...           ...                 ...              ...
# 240            4.140467             7                 123              104
# 241            4.048768             3                 123               16
# 242            4.140467             7                 124              104
# 243            4.140467             7                 125              104
# 244            4.140467             8                 125              110
#
#      State  Project size  Project organization  BG  Project Health  On-hold
# 0        3             3                    21   5               1        1
# 1        3             1                    21   3               3        2
# 2        3             2                    21   3               3        1
# 3        3             3                    21   3               1        2
# 4        3             2                    21   3               1        1
# ..     ...           ...                   ...  ..             ...      ...
# 240      3             2                     6   1               1        1
# 241      3             1                     5   1               1        1
# 242      3             2                     6   1               1        1
# 243      3             2                     6   1               1        1
# 244      3             3                     6   1               1        1
#
# [225 rows x 15 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                     Correlación simple  Coeficiente múltiple
# Geographical scope            0.082748              0.012237
# Project size                  0.115164              0.908647
# Project Type                  0.217320              0.446746

# %%
sns.scatterplot(x='Project Type', y='Project organization', color="pink", data=df_num)
sns.scatterplot(x='Project Type', y='PrediccionesProjectorg', color="orange", data=df_num)
# Out:
# <Axes: xlabel='Project Type', ylabel='Project organization'>

# %% [markdown]
# ## BG

# %% [markdown]
# Geographical scope (0.23)
# Project organization (0.15)
# State (0.10 aprox.)

# %%
Vars_Indep= df_num[['Geographical scope', 'Project organization','State']]
Var_Dep= df_num['BG']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Geographical scope', 'Project organization', 'State'],
#        dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([-0.01535784,  0.00412211, -0.73454926]),
#  'rank_': 3,
#  'singular_': array([512.39114236, 106.93134452,   3.74645193]),
#  'intercept_': np.float64(7.1814138888217975)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['Geographical scope', 'Project organization','State']])
y_pred
# Out:
# array([5.04897252, 5.03361468, 5.01825684, 5.01825684, 5.002899  ,
#        4.92570954, 4.92684013, 4.95682547, 4.95270336, 4.88375812,
#        4.95908665, 4.93847611, 4.95908665, 4.91075194, 4.89127199,
#        4.89127199, 4.87591415, 4.81109102, 4.84932057, 4.86693959,
#        4.81860489, 4.81860489, 4.81448278, 4.81448278, 4.81860489,
#        4.81860489, 5.49245312, 4.75790386, 4.75790386, 4.75790386,
#        4.75790386, 4.75790386, 4.75790386, 4.75790386, 4.75790386,
#        4.76727866, 4.77253136, 4.76840925, 4.76840925, 4.6953419 ,
#        4.67586195, 4.66050411, 4.64926838, 4.62566632, 4.61855269,
#        4.66090436, 4.68676759, 4.66615705, 4.63018867, 4.55299921,
#        4.60359509, 4.58411514, 4.57287941, 4.5687573 , 4.57813211,
#        4.5297974 , 4.48970691, 4.47022696, 5.20065412, 4.47022696,
#        4.47022696, 4.4960902 , 4.4960902 , 4.46012182, 4.47661025,
#        4.46125241, 4.45001667, 4.45001667, 4.45001667, 4.37282721,
#        4.35746937, 4.33386731, 4.38446319, 4.30315163, 4.29191589,
#        4.34251177, 4.33838967, 4.34251177, 4.32715393, 4.32303182,
#        4.32715393, 4.31179609, 4.31179609, 4.31179609, 4.25109506,
#        5.00326334, 4.9785307 , 4.24398144, 4.26459197, 4.96317285,
#        4.30694364, 4.9879055 , 4.21326575, 4.21738786, 4.22150997,
#        4.21326575, 4.22150997, 4.26386163, 4.26386163, 4.13720688,
#        4.20016909, 4.20016909, 4.18368065, 4.18893335, 4.17357551,
#        4.14997345, 4.13873772, 4.14285982, 4.14285982, 4.14285982,
#        4.14285982, 4.12750198, 4.12750198, 4.85792913, 4.12750198,
#        4.80959443, 4.12151894, 5.52991644, 4.09904747, 4.09904747,
#        4.07431483, 4.09904747, 3.97239272, 4.03535493, 4.03535493,
#        4.03535493, 4.01999708, 4.01999708, 3.9263192 , 3.9892814 ,
#        3.98515929, 3.9892814 , 3.97392356, 3.97392356, 4.68899287,
#        3.95444361, 3.92971096, 3.95444361, 3.95444361, 3.9061089 ,
#        3.92785003, 3.92372792, 3.92372792, 3.91249219, 3.91249219,
#        3.89301224, 3.86415748, 3.8776544 , 4.55562474, 3.82519758,
#        3.84693871, 3.86043562, 3.84507778, 3.84919989, 3.82971994,
#        3.82971994, 3.83384204, 3.82260631, 3.79900425, 3.79900425,
#        3.76303587, 3.79601273, 3.76303587, 3.76303587, 3.76303587,
#        3.76303587, 3.76303587, 3.68172431, 3.66224436, 3.66749705,
#        4.40204631, 3.67161916, 3.72221504, 3.61617083, 3.59669088,
#        3.57721093, 3.63605103, 3.61657108, 3.62069318, 3.63419009,
#        3.61471014, 3.61471014, 3.61471014, 3.60759652, 3.61171862,
#        3.58399446, 3.57688083, 3.55740088, 3.50906618, 3.49370834,
#        3.49783044, 3.44125153, 3.40116104, 3.42702427, 3.37456746,
#        3.44577388, 3.40156128, 3.39032555, 3.39032555, 3.39032555,
#        3.37496771, 3.37496771, 3.3708456 , 3.29777825, 3.34425202,
#        3.34012991, 3.30416153, 3.31765844, 3.31765844, 3.2487132 ,
#        3.27869854, 3.2633407 , 3.25210497, 3.23674712, 3.23262502,
#        3.23262502, 3.21726717, 3.20603144, 3.20603144, 3.12884198,
#        3.11348414, 3.10936203, 3.0981263 , 3.08276846, 3.08276846])

# %%
df_num.insert(0, 'PrediccionesProjectBG', y_pred)
df_num
# Out:
#      PrediccionesProjectBG  PrediccionesProjectorg  PrediccionesProjectSize  \
# 0                 5.048973               19.413198                 1.821110
# 1                 5.033615               17.608142                 2.060787
# 2                 5.018257               18.529026                 2.234670
# 3                 5.018257               19.437672                 2.060787
# 4                 5.002899               18.541263                 1.821110
# ..                     ...                     ...                      ...
# 240               3.113484               19.550746                 2.044498
# 241               3.109362               16.855116                 1.529553
# 242               3.098126               19.562984                 2.044498
# 243               3.082768               19.575221                 2.044498
# 244               3.082768               20.930613                 2.094611
#
#      PrediccionesState  PrediccionesProject manager  \
# 0             3.001301                    58.176993
# 1             2.877433                    45.086741
# 2             3.001301                    51.631867
# 3             2.877433                    58.176993
# 4             3.001301                    51.631867
# ..                 ...                          ...
# 240           2.955458                    53.113430
# 241           2.918699                    52.494557
# 242           2.955458                    53.113430
# 243           2.955458                    53.113430
# 244           2.964027                    58.176993
#
#      PrediccionesGeographical scope  PrediccionesTname0  Project Type  \
# 0                         62.928556            5.515942             8
# 1                         69.704659            5.515942             8
# 2                         69.704659            5.515942             8
# 3                         69.704659            5.515942             8
# 4                         69.704659            5.515942             8
# ..                              ...                 ...           ...
# 240                       71.360964            4.140467             7
# 241                       66.445304            4.048768             3
# 242                       71.360964            4.140467             7
# 243                       71.360964            4.140467             7
# 244                       72.523932            4.140467             8
#
#      Geographical scope  Project manager  State  Project size  \
# 0                     1                8      3             3
# 1                     2               59      3             1
# 2                     3               96      3             2
# 3                     3               59      3             3
# 4                     4                8      3             2
# ..                  ...              ...    ...           ...
# 240                 123              104      3             2
# 241                 123               16      3             1
# 242                 124              104      3             2
# 243                 125              104      3             2
# 244                 125              110      3             3
#
#      Project organization  BG  Project Health  On-hold
# 0                      21   5               1        1
# 1                      21   3               3        2
# 2                      21   3               3        1
# 3                      21   3               1        2
# 4                      21   3               1        1
# ..                    ...  ..             ...      ...
# 240                     6   1               1        1
# 241                     5   1               1        1
# 242                     6   1               1        1
# 243                     6   1               1        1
# 244                     6   1               1        1
#
# [225 rows x 16 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                       Correlación simple  Coeficiente múltiple
# Geographical scope             -0.227722             -0.015358
# Project organization           -0.015659              0.004122
# State                          -0.084619             -0.734549

# %%
sns.scatterplot(x='Project Type', y='BG', color="pink", data=df_num)
sns.scatterplot(x='Project Type', y='PrediccionesProjectBG', color="orange", data=df_num)
# Out:
# <Axes: xlabel='Project Type', ylabel='BG'>

# %% [markdown]
# ## Project Health

# %% [markdown]
# On-hold (0.23)
#
# Project size (0.10 aprox.)

# %%
Vars_Indep= df_num[['On-hold','Project size']]
Var_Dep= df_num['Project Health']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['On-hold', 'Project size'], dtype=object),
#  'n_features_in_': 2,
#  'coef_': array([ 0.47190676, -0.12186373]),
#  'rank_': 2,
#  'singular_': array([11.35454987,  6.13612052]),
#  'intercept_': np.float64(1.1286755415575604)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['On-hold','Project size']])
y_pred
# Out:
# array([1.23499112, 1.95062533, 1.35685485, 1.70689788, 1.35685485,
#        1.47871857, 1.8287616 , 1.47871857, 1.47871857, 1.47871857,
#        1.8287616 , 1.47871857, 1.23499112, 1.47871857, 1.35685485,
#        1.35685485, 1.35685485, 1.23499112, 1.23499112, 1.47871857,
#        1.95062533, 1.47871857, 1.35685485, 1.35685485, 1.70689788,
#        1.35685485, 1.70689788, 1.35685485, 1.8287616 , 1.35685485,
#        1.35685485, 1.47871857, 1.8287616 , 1.8287616 , 1.8287616 ,
#        1.47871857, 1.23499112, 1.35685485, 1.35685485, 1.23499112,
#        1.47871857, 1.47871857, 1.23499112, 1.8287616 , 1.47871857,
#        1.8287616 , 1.47871857, 1.47871857, 1.35685485, 1.95062533,
#        1.35685485, 1.35685485, 1.47871857, 1.35685485, 1.95062533,
#        1.23499112, 1.8287616 , 1.23499112, 1.70689788, 1.35685485,
#        1.23499112, 1.23499112, 1.23499112, 1.35685485, 1.35685485,
#        1.35685485, 1.23499112, 1.23499112, 1.47871857, 1.47871857,
#        1.47871857, 1.47871857, 1.35685485, 1.47871857, 1.47871857,
#        1.47871857, 1.35685485, 1.70689788, 1.47871857, 1.35685485,
#        1.35685485, 1.70689788, 1.35685485, 1.47871857, 1.47871857,
#        1.8287616 , 1.8287616 , 1.23499112, 1.23499112, 1.70689788,
#        1.23499112, 1.70689788, 1.8287616 , 1.23499112, 1.35685485,
#        1.70689788, 1.23499112, 1.23499112, 1.23499112, 1.95062533,
#        1.35685485, 1.47871857, 1.47871857, 1.95062533, 1.23499112,
#        1.47871857, 1.35685485, 1.95062533, 1.70689788, 1.35685485,
#        1.23499112, 1.35685485, 1.47871857, 1.35685485, 1.47871857,
#        1.70689788, 1.23499112, 1.35685485, 1.47871857, 1.47871857,
#        1.47871857, 1.47871857, 1.95062533, 1.47871857, 1.47871857,
#        1.47871857, 1.23499112, 1.47871857, 1.95062533, 1.47871857,
#        1.35685485, 1.70689788, 1.47871857, 1.35685485, 1.35685485,
#        1.35685485, 1.35685485, 1.35685485, 1.35685485, 1.23499112,
#        1.95062533, 1.35685485, 1.35685485, 1.23499112, 1.23499112,
#        1.35685485, 1.35685485, 1.35685485, 1.35685485, 1.23499112,
#        1.35685485, 1.35685485, 1.23499112, 1.35685485, 1.23499112,
#        1.8287616 , 1.35685485, 1.47871857, 1.8287616 , 1.23499112,
#        1.23499112, 1.23499112, 1.35685485, 1.47871857, 1.47871857,
#        1.35685485, 1.35685485, 1.35685485, 1.95062533, 1.47871857,
#        1.70689788, 1.23499112, 1.35685485, 1.47871857, 1.35685485,
#        1.8287616 , 1.8287616 , 1.35685485, 1.23499112, 1.35685485,
#        1.70689788, 1.35685485, 1.35685485, 1.95062533, 1.47871857,
#        1.70689788, 1.47871857, 1.23499112, 1.47871857, 1.35685485,
#        1.70689788, 1.35685485, 1.47871857, 1.70689788, 1.47871857,
#        1.23499112, 1.8287616 , 1.47871857, 1.35685485, 1.35685485,
#        1.23499112, 1.47871857, 1.35685485, 1.47871857, 1.35685485,
#        1.35685485, 1.35685485, 1.47871857, 1.35685485, 1.35685485,
#        1.35685485, 1.35685485, 1.47871857, 1.35685485, 1.35685485,
#        1.35685485, 1.8287616 , 1.95062533, 1.70689788, 1.47871857,
#        1.35685485, 1.47871857, 1.35685485, 1.35685485, 1.23499112])

# %%
df_num.insert(0, 'PrediccionesProjectH', y_pred)
df_num
# Out:
#      PrediccionesProjectH  PrediccionesProjectBG  PrediccionesProjectorg  \
# 0                1.234991               5.048973               19.413198
# 1                1.950625               5.033615               17.608142
# 2                1.356855               5.018257               18.529026
# 3                1.706898               5.018257               19.437672
# 4                1.356855               5.002899               18.541263
# ..                    ...                    ...                     ...
# 240              1.356855               3.113484               19.550746
# 241              1.478719               3.109362               16.855116
# 242              1.356855               3.098126               19.562984
# 243              1.356855               3.082768               19.575221
# 244              1.234991               3.082768               20.930613
#
#      PrediccionesProjectSize  PrediccionesState  PrediccionesProject manager  \
# 0                   1.821110           3.001301                    58.176993
# 1                   2.060787           2.877433                    45.086741
# 2                   2.234670           3.001301                    51.631867
# 3                   2.060787           2.877433                    58.176993
# 4                   1.821110           3.001301                    51.631867
# ..                       ...                ...                          ...
# 240                 2.044498           2.955458                    53.113430
# 241                 1.529553           2.918699                    52.494557
# 242                 2.044498           2.955458                    53.113430
# 243                 2.044498           2.955458                    53.113430
# 244                 2.094611           2.964027                    58.176993
#
#      PrediccionesGeographical scope  PrediccionesTname0  Project Type  \
# 0                         62.928556            5.515942             8
# 1                         69.704659            5.515942             8
# 2                         69.704659            5.515942             8
# 3                         69.704659            5.515942             8
# 4                         69.704659            5.515942             8
# ..                              ...                 ...           ...
# 240                       71.360964            4.140467             7
# 241                       66.445304            4.048768             3
# 242                       71.360964            4.140467             7
# 243                       71.360964            4.140467             7
# 244                       72.523932            4.140467             8
#
#      Geographical scope  Project manager  State  Project size  \
# 0                     1                8      3             3
# 1                     2               59      3             1
# 2                     3               96      3             2
# 3                     3               59      3             3
# 4                     4                8      3             2
# ..                  ...              ...    ...           ...
# 240                 123              104      3             2
# 241                 123               16      3             1
# 242                 124              104      3             2
# 243                 125              104      3             2
# 244                 125              110      3             3
#
#      Project organization  BG  Project Health  On-hold
# 0                      21   5               1        1
# 1                      21   3               3        2
# 2                      21   3               3        1
# 3                      21   3               1        2
# 4                      21   3               1        1
# ..                    ...  ..             ...      ...
# 240                     6   1               1        1
# 241                     5   1               1        1
# 242                     6   1               1        1
# 243                     6   1               1        1
# 244                     6   1               1        1
#
# [225 rows x 17 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#               Correlación simple  Coeficiente múltiple
# On-hold                 0.227482              0.471907
# Project size           -0.086617             -0.121864

# %%
sns.scatterplot(x='On-hold', y='Project Health', color="pink", data=df_num)
sns.scatterplot(x='On-hold', y='PrediccionesProjectH', color="orange", data=df_num)
# Out:
# <Axes: xlabel='On-hold', ylabel='Project Health'>

# %% [markdown]
# ## On-hold

# %% [markdown]
# Project Health (0.23)
# State (0.22)
# Project Type (0.10 aprox.)

# %%
Vars_Indep= df_num[['Project Health','State','Project Type']]
Var_Dep= df_num['On-hold']

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(Vars_Indep, Var_Dep)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Project Health', 'State', 'Project Type'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.10875381, -0.31813821, -0.00802913]),
#  'rank_': 3,
#  'singular_': array([48.44345654, 12.15783137,  3.71854055]),
#  'intercept_': np.float64(2.0356287274381075)}

# %%
model.score(Vars_Indep,Var_Dep)
y_pred= model.predict(X=df_num[['Project Health','State','Project Type']])
y_pred
# Out:
# array([1.1257349 , 1.34324253, 1.34324253, 1.1257349 , 1.1257349 ,
#        1.11770577, 1.39944642, 1.11770577, 1.18193879, 1.14982228,
#        1.29069261, 1.32718428, 1.14179316, 1.34324253, 1.18193879,
#        1.18193879, 1.18193879, 1.36732991, 1.36732991, 1.18193879,
#        1.1257349 , 1.1257349 , 1.18193879, 1.18193879, 1.1257349 ,
#        1.1257349 , 1.60883082, 1.18193879, 1.18193879, 1.18193879,
#        1.18193879, 1.18193879, 1.18193879, 1.39944642, 1.18193879,
#        1.14982228, 1.34324253, 1.18193879, 1.18193879, 1.1257349 ,
#        1.16588054, 1.16588054, 1.1257349 , 1.18193879, 1.11770577,
#        1.18193879, 1.35930079, 1.38338817, 1.18193879, 1.15785141,
#        1.13376403, 1.39944642, 1.3352134 , 1.18193879, 1.3352134 ,
#        1.14982228, 1.36732991, 1.34324253, 1.60883082, 1.1257349 ,
#        1.1257349 , 1.34324253, 1.11770577, 1.14982228, 1.39944642,
#        1.18193879, 1.3352134 , 1.1257349 , 1.1257349 , 1.11770577,
#        1.1257349 , 1.18193879, 1.18193879, 1.18193879, 1.16588054,
#        1.1257349 , 1.18193879, 1.1257349 , 1.1257349 , 1.18193879,
#        1.34324253, 1.1257349 , 1.1257349 , 1.1257349 , 1.29069261,
#        1.57671431, 1.57671431, 1.14982228, 1.17390967, 1.57671431,
#        1.14982228, 1.57671431, 1.14982228, 1.14982228, 1.14982228,
#        1.14982228, 1.14982228, 1.1257349 , 1.1257349 , 1.18193879,
#        1.18193879, 1.18193879, 1.36732991, 1.3352134 , 1.1257349 ,
#        1.18193879, 1.18193879, 1.34324253, 1.1257349 , 1.1257349 ,
#        1.1257349 , 1.1257349 , 1.1257349 , 1.60883082, 1.1257349 ,
#        1.46796049, 1.1257349 , 1.7860987 , 1.18193879, 1.14179316,
#        1.10967665, 1.35930079, 1.39944642, 1.1257349 , 1.1257349 ,
#        1.1257349 , 1.1257349 , 1.34324253, 1.39944642, 1.34324253,
#        1.18193879, 1.1257349 , 1.1257349 , 1.34324253, 1.60883082,
#        1.18193879, 1.36732991, 1.18193879, 1.18193879, 1.14982228,
#        1.11770577, 1.18193879, 1.18193879, 1.1257349 , 1.1257349 ,
#        1.18193879, 1.14982228, 1.18193879, 1.60883082, 1.1257349 ,
#        1.18193879, 1.34324253, 1.1257349 , 1.34324253, 1.1257349 ,
#        1.34324253, 1.34324253, 1.39944642, 1.1257349 , 1.1257349 ,
#        1.10967665, 1.18193879, 1.10967665, 1.14982228, 1.14982228,
#        1.10967665, 1.10967665, 1.1257349 , 1.15785141, 1.18193879,
#        1.60883082, 1.34324253, 1.1257349 , 1.16588054, 1.18193879,
#        1.39944642, 1.35127166, 1.18193879, 1.14982228, 1.1257349 ,
#        1.1257349 , 1.1257349 , 1.1257349 , 1.39944642, 1.14179316,
#        1.1257349 , 1.18193879, 1.1257349 , 1.18193879, 1.39944642,
#        1.14982228, 1.34324253, 1.16588054, 1.14982228, 1.1257349 ,
#        1.1257349 , 1.18193879, 1.1257349 , 1.1257349 , 1.36732991,
#        1.1257349 , 1.11770577, 1.18193879, 1.1257349 , 1.1257349 ,
#        1.18193879, 1.2585761 , 1.10967665, 1.10967665, 1.1257349 ,
#        1.18193879, 1.18193879, 1.34324253, 1.1257349 , 1.18193879,
#        1.18193879, 1.39944642, 1.3352134 , 1.36732991, 1.11770577,
#        1.13376403, 1.16588054, 1.13376403, 1.13376403, 1.1257349 ])

# %%
df_num.insert(0, 'PrediccionesProjectoh', y_pred)
df_num
# Out:
#      PrediccionesProjectoh  PrediccionesProjectH  PrediccionesProjectBG  \
# 0                 1.125735              1.234991               5.048973
# 1                 1.343243              1.950625               5.033615
# 2                 1.343243              1.356855               5.018257
# 3                 1.125735              1.706898               5.018257
# 4                 1.125735              1.356855               5.002899
# ..                     ...                   ...                    ...
# 240               1.133764              1.356855               3.113484
# 241               1.165881              1.478719               3.109362
# 242               1.133764              1.356855               3.098126
# 243               1.133764              1.356855               3.082768
# 244               1.125735              1.234991               3.082768
#
#      PrediccionesProjectorg  PrediccionesProjectSize  PrediccionesState  \
# 0                 19.413198                 1.821110           3.001301
# 1                 17.608142                 2.060787           2.877433
# 2                 18.529026                 2.234670           3.001301
# 3                 19.437672                 2.060787           2.877433
# 4                 18.541263                 1.821110           3.001301
# ..                      ...                      ...                ...
# 240               19.550746                 2.044498           2.955458
# 241               16.855116                 1.529553           2.918699
# 242               19.562984                 2.044498           2.955458
# 243               19.575221                 2.044498           2.955458
# 244               20.930613                 2.094611           2.964027
#
#      PrediccionesProject manager  PrediccionesGeographical scope  \
# 0                      58.176993                       62.928556
# 1                      45.086741                       69.704659
# 2                      51.631867                       69.704659
# 3                      58.176993                       69.704659
# 4                      51.631867                       69.704659
# ..                           ...                             ...
# 240                    53.113430                       71.360964
# 241                    52.494557                       66.445304
# 242                    53.113430                       71.360964
# 243                    53.113430                       71.360964
# 244                    58.176993                       72.523932
#
#      PrediccionesTname0  Project Type  Geographical scope  Project manager  \
# 0              5.515942             8                   1                8
# 1              5.515942             8                   2               59
# 2              5.515942             8                   3               96
# 3              5.515942             8                   3               59
# 4              5.515942             8                   4                8
# ..                  ...           ...                 ...              ...
# 240            4.140467             7                 123              104
# 241            4.048768             3                 123               16
# 242            4.140467             7                 124              104
# 243            4.140467             7                 125              104
# 244            4.140467             8                 125              110
#
#      State  Project size  Project organization  BG  Project Health  On-hold
# 0        3             3                    21   5               1        1
# 1        3             1                    21   3               3        2
# 2        3             2                    21   3               3        1
# 3        3             3                    21   3               1        2
# 4        3             2                    21   3               1        1
# ..     ...           ...                   ...  ..             ...      ...
# 240      3             2                     6   1               1        1
# 241      3             1                     5   1               1        1
# 242      3             2                     6   1               1        1
# 243      3             2                     6   1               1        1
# 244      3             3                     6   1               1        1
#
# [225 rows x 18 columns]

# %%
corr = df_num.corr()
# Correlaciones simples de la variable dependiente con las independientes
corr_simple = df_num[Vars_Indep.columns.tolist() + [Var_Dep.name]].corr()[Var_Dep.name].drop(Var_Dep.name)

# Coeficientes de regresión múltiple
coef_mult = pd.Series(model.coef_, index=Vars_Indep.columns)

# Crear tabla comparativa
comparacion = pd.DataFrame({
    'Correlación simple': corr_simple,
    'Coeficiente múltiple': coef_mult
})

print(comparacion)
# Out:
#                 Correlación simple  Coeficiente múltiple
# Project Health            0.227482              0.108754
# State                    -0.221179             -0.318138
# Project Type             -0.080656             -0.008029

# %%
sns.scatterplot(x='Project Health', y='On-hold', color="pink", data=df_num)
sns.scatterplot(x='Project Health', y='PrediccionesProjectH', color="orange", data=df_num)
# Out:
# <Axes: xlabel='Project Health', ylabel='On-hold'>
